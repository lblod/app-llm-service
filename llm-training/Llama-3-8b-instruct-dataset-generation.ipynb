# %%
import os

def set_environment_variables():
    os.environ['OPENAI_DEPLOYMENT_ENDPOINT'] = 'https://abb-openai.openai.azure.com/'
    os.environ['OPENAI_API_KEY'] = '29c48fb759054b38891f07b5a467e124'
    os.environ['OPENAI_DEPLOYMENT_NAME'] = 'gpt-4o'
    os.environ['OPENAI_DEPLOYMENT_VERSION'] = '2024-02-01'

    os.environ['DEEPINFRA_API_KEY'] = 'iWkTLk0avn6IpwrwUdsm6xPglfXlvyrA'
    os.environ['DEEPINFRA_ENDPOINT'] = 'https://api.deepinfra.com/v1/openai'
    os.environ['DEEPINFRA_MODEL_NAME'] = 'meta-llama/Meta-Llama-3-70B-Instruct'
    
    os.environ['LOKAALBESLIST_LOCATION_ID'] = 'ce94eeae827cdc5c00f3f2f4276ff628580edefb3aa5861e4669b0c5d93adc57'
    os.environ['LOKAALBESLIST_SEARCH_ENDPOINT'] = 'https://lokaalbeslist.vlaanderen.be/search/agenda-items/search'

# Call the function to set the environment variables
set_environment_variables()

# %% [markdown]
# # What is this notebook for?
#
# The following Jupyter notebook contains the code needed to create an artificial dataset for context-aware tasks such as keyword extraction, classification, summarization, and translation.
#
# ## General structure of a context-aware prompt
#
# All prompts are generated according to the following template:
#
# ```
# ####
# Context: {context}
# ####
# {task}
# ```
#
# - **Context**: The document, text, JSON object, or file that the model should use to derive a response. It should contain all the necessary information and facts to form a correct response. The goal is to only use this as the source of information and facts.
# - **Task**: The action that needs to be performed with the context in mind, such as "translate the context", "get x from the context", etc.
#
# When training a model, the prompt is part of the user message. Each sample is a conversation containing a system message, user message, and assistant message.
# - **System message**: Describes the broader context or general behavior of how the agent should act (e.g., "the AI should stick only to the context").
# - **User message**: Contains the prompt.
# - **Assistant message**: Contains the answer to the prompt.
#
# To train a model, we should create samples that contain these three necessary components. However, additional metadata for further analysis is also stored, which is not technically needed.
#
# ## How it works
#
# Since no 'real' data exists, artificial data is generated for the tasks using a more robust model (for the existing dataset, this was GPT-4o). We simply create the system message and prompt, send it to GPT-4o or any other model to generate a response, and store it. This process is repeated for every task.
#
# Generally, we want two types of output: JSON objects for further processing and storing within other applications, and text format.
#
# In most cases, we want to further process the results, making JSON an ideal format. To nudge the model into generating JSON, we use the following system message (see `generate_json_prompt`):
#
# ```
# system_message = "Your task is to generate responses in JSON format. Ensure that your output strictly follows the provided JSON structure. Each key in the JSON should be correctly populated according to the instructions given. Pay attention to details and ensure the JSON is well-formed and valid."
# ```
#
# For RAG (Retrieval-Augmented Generation) tasks, JSON is not expected, but all information should be derived from the context. To make this requirement extra clear, we use the following system message (see `generate_rag_prompt`):
#
# ```
# system_message = """You are a Retrieval Augmented Generator (RAG). Your task is to complete tasks and answer questions based on the provided context.
# 1. Language: Respond only in Dutch.
# 2. Relevance: Use only the information from the provided context to form your response. If the context does not contain relevant information to the question or task, respond with 'Sorry, ik kan de gevraagde informatie niet terugvinden.'
# 3. Only respond to questions related to the context."""
# ```
#
#
# The typical approach for generating samples is as follows:
#
# 1. **Create a function to generate the prompt, system message, context for the task:**
#     ```python
#     prompt_string, system_message, task_string, context = generate_llm_task(data)
#     ```
#
# 2. **Set `json_mode` to `True` if JSON format is desired:**
#     ```python
#     response = generate_response_openai(system_message, prompt_string, stream=False, json_mode=True)
#     ```
#
# 3. **Extract the JSON response and save it togheter with the metadata to file**
#     ```python
#     response_json = extract_json(response)
#     if response_json is not None:
#         # Create metadata for the task
#         task_info = get_task_info("keywords_bpmn", "keywords", "keywords_bpmn", "bpmn", "json")
#         # Save the system message, user input, task instruction, context, and response to a file for later use
#         save_results_to_file(task_info, file_path, task_string, context, system_message, prompt_string, response)
#     return response_json
#     ```

# %% [markdown]
# # Configurations and setup

# %%
from openai import AzureOpenAI, OpenAI
import json
import uuid
import os

OPENAI_DEPLOYMENT_ENDPOINT = os.environ['OPENAI_DEPLOYMENT_ENDPOINT']
OPENAI_API_KEY = os.environ['OPENAI_API_KEY']
OPENAI_DEPLOYMENT_NAME = os.environ['OPENAI_DEPLOYMENT_NAME']
OPENAI_DEPLOYMENT_VERSION = os.environ['OPENAI_DEPLOYMENT_VERSION']

DEEPINFRA_API_KEY = os.environ['DEEPINFRA_API_KEY']
DEEPINFRA_ENDPOINT = os.environ['DEEPINFRA_ENDPOINT']
DEEPINFRA_MODEL_NAME = os.environ['DEEPINFRA_MODEL_NAME']

LOKAALBESLIST_LOCATION_ID = os.environ['LOKAALBESLIST_LOCATION_ID']
LOKAALBESLIST_SEARCH_ENDPOINT = os.environ['LOKAALBESLIST_SEARCH_ENDPOINT']

# Create an OpenAI client using Azure endpoint
client = AzureOpenAI(
    api_key=OPENAI_API_KEY,  
    api_version=OPENAI_DEPLOYMENT_VERSION,
    azure_endpoint=OPENAI_DEPLOYMENT_ENDPOINT
)

# Create an OpenAI client using llama endpoint
client = OpenAI(
    api_key=DEEPINFRA_API_KEY,
    base_url=DEEPINFRA_ENDPOINT,
)

# %%
import random
import json
import re

#General response generation function for openai and ollama

def generate_response_openai(system_message,prompt_string, stream=False, json_mode=False, context_length=4096):

    # Set the response_format based on the json_mode parameter
    response_format = {"type": "json_object"} if json_mode else None

    response = client.chat.completions.create(
        model= OPENAI_DEPLOYMENT_NAME,
        response_format=response_format,
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": prompt_string},
        ],
        temperature=0.0,
        max_tokens=context_length,
        stream=stream,
        )

    return response

#General structuring functions for prompting

def generate_prompt(task, context, system_message, include_system_message=True):
    if include_system_message:
        return f"####\nContext: {context}\n####\nInstructions:  {system_message} \n####\n{task}", system_message
    else:
        return f"####\nContext: {context}\n####\n{task}", system_message

# Specific prompt generation functions where json responses are required
def generate_json_prompt(task, context, include_system_message=True):
    system_message = "Your task is to generate responses in JSON format. Ensure that your output strictly follows the provided JSON structure. Each key in the JSON should be correctly populated according to the instructions given. Pay attention to details and ensure the JSON is well-formed and valid."
    return generate_prompt(task, context, system_message, include_system_message)

# Specific prompt generation functions for RAG tasks
def generate_rag_prompt(task, context, include_system_message=True):
    system_message = """You are a Retrieval Augmented Generator (RAG). Your task is to complete tasks and answer questions based on the provided context.
1. Language: Respond only in Dutch.
2. Relevance: Use only the information from the provided context to form your response. If the context does not contain relevant information to the question or task, respond with 'Sorry, ik kan de gevraagde informatie niet terugvinden.'
3. Only respond to questions related to the context."""
    return generate_prompt(task, context, system_message, include_system_message)



#Cleaning and processing returned data

def clean_json_string(json_string):
    pattern = r'^```json\s*(.*?)\s*```$'
    cleaned_string = re.sub(pattern, r'\1', json_string, flags=re.DOTALL)
    return cleaned_string.strip()

def extract_json(response):
    #remove trailing and leading json formatting
    response_text = response.choices[0].message.content
    response_text = clean_json_string(response_text)
    try:
        return json.loads(response_text)
    except json.JSONDecodeError:
        print(f"Skipping invalid JSON in response: {response_text}")
        return None

def clean_tasks(tasks):
    cleaned_tasks = []

    for task in tasks:
        if 'response' not in task or task['response'] is None:
            continue
        response = clean_json_string(task['response'])
        try:
            json_response = json.loads(response)
        except json.JSONDecodeError:
            print(f"Skipping invalid JSON in response: {response}")
            continue
        cleaned_tasks.append(task)

    return cleaned_tasks

def balance_tasks(tasks, max_per_freq=150):
    frequency = {}
    balanced_tasks = []

    for task in tasks:
        response = task['response']
        json_response = json.loads(response)
        num_translations = len(json_response['translations'])
        if num_translations not in frequency:
            frequency[num_translations] = 0
        if frequency[num_translations] < max_per_freq:
            frequency[num_translations] += 1
            balanced_tasks.append(task)

    sorted_frequency = dict(sorted(frequency.items(), key=lambda item: item[0]))
    print(sorted_frequency)

    return balanced_tasks

def store_tasks(tasks, output_file):
    with open(output_file, 'w') as f:
        for task in tasks:
            json.dump(task, f)
            f.write('\n')



#Fuction to load
def load_data_from_file(filename):
    data = []
    with open(filename, 'r') as f:
        for line in f:
            data.append(json.loads(line))
    return data

#Function to save samples and responses to file
def get_task_info(task_name, category, sub_category ,  input_data_type = "bpmn", response_data_type ="json" , language = "Dutch"):
    task_info = {
    "task_name": task_name,
    "category": category,
    "sub_category": sub_category,
    "input_data_type": input_data_type,
    "response_data_type": response_data_type,
    "language": language
    }
    return task_info

def save_results_to_file(task_info, user_input, task, context, system_message, prompt_string, response):
    # Create the filename
    filename = f"{task_info['task_name']}_openai_dataset.jsonl"

    #extract message and meta from response
    response_json = json.loads(response.model_dump_json())
    response_text = response_json["choices"][0].pop("message", {"content":"Sorry, ik kan de gevraagde informatie niet terugvinden."})["content"]

    #use remaining information as meta
    meta = response_json
    
    meta["task_info"] = task_info

    # Create the data to save
    data = {
        'id': str(uuid.uuid4()),  # Generate a new UUID for the ID
        'user_input': user_input,
        'task': task,
        'context': context,
        'system_message': system_message,
        'prompt': prompt_string,
        'response': response_text,
        'meta': meta
    }

    # Save the data to the file
    with open(filename, 'a' if os.path.exists(filename) else 'w') as f:  # Append to the file if it exists
        f.write(json.dumps(data) + '\n')  # Write the data as a JSON string followed by a newline

    #print(f"Results saved to {filename}")

# %% [markdown]
# # Keyword extraction task

# %%
import os
import time
from tqdm import tqdm
from library.BPMNGraph import BPMNGraph

def generate_keyword_task(context, include_system_message=True):

    task = """
    
        You are an expert in extracting keywords from text data based on a provided context. Your task is to identify the most relevant keywords in the given text provided in the context.
    
        Extract the keywords from the document provided in context. Ensure that the keywords are accurate and specific to the context provided.
        Focus on general themes, organizations, locations, etc. These keywords should provide a high-level overview of the document's content.
        Order the keywords based on their relevance and importance in the document.
    
        Desired Output:
        Output the keywords in a JSON format, like this:
        {
            "keywords": ["keyword1", "keyword2", "keyword3"]
        }
    """

    prompt, system = generate_json_prompt(task, context, include_system_message)

    return prompt, system, task, {"context": context}

def get_data_bpmn(graph, with_documentation=True):
    translation_jobs = []
    for id, node in graph.get_nodes():
        node_name = node["name"]
        
        if with_documentation:
            node_documentation = node["documentation"]
            if node_name != '' or node_documentation != '':
                translation_jobs.append({
                    'id': id,
                    'name': node_name,
                    'documentation': node_documentation
                })
        else:
            if node_name != '':
                translation_jobs.append({
                    'id': id,
                    'name': node_name
                })

    return translation_jobs

import json

def extract_keywords_text(text):
    # Generate the classification task
    prompt_string, system_message, _, _ = generate_keyword_task(text)

    # Generate the response using OpenAI (or any other method)
    response = generate_response_openai(system_message, prompt_string, stream=False, json_mode=True)

    return response.choices[0].message.content

def extract_keywords_agendapunt(agendapunt):
    # Convert the JSON object to a string
    text = json.dumps(agendapunt)

    # Generate the classification task
    prompt_string, system_message, task_string, context = generate_keyword_task(text)

    # Generate the response using OpenAI (or any other method)
    response = generate_response_openai(system_message, prompt_string, stream=False, json_mode=True)
    response_json = extract_json(response)

    if response_json is not None:
        task_info = get_task_info("keywords_agendapunt", "keywords", "keywords_agendapunt", "json", "json")
        save_results_to_file(task_info, text, task_string, context, system_message, prompt_string, response)

    return response_json

def extract_keywords_bpmn(file_path):
    # Create a BPMN graph
    graph = BPMNGraph(file_path)

    classification_data = get_data_bpmn(graph)
    classification_text = json.dumps(classification_data)

    prompt_string, system_message, task_string, context = generate_keyword_task(classification_text)
    response = generate_response_openai(system_message,prompt_string, stream=False, json_mode=True)
    response_json = extract_json(response)
    if response_json is not None:
        task_info = get_task_info("keywords_bpmn", "keywords", "keywords_bpmn", "bpmn", "json")
        save_results_to_file(task_info, file_path, task_string, context, system_message, prompt_string, response)
    return response_json

def extract_bpmn_folder(folder_path, taxonomy):
    # Get all .bpmn files in the folder
    bpmn_files = [f for f in os.listdir(folder_path) if f.endswith('.bpmn')]

    # Translate each file, progress bar
    for file in tqdm(bpmn_files, "Extracting keywords BPMN files"):
        file_path = os.path.join(folder_path, file)
        extract_keywords_bpmn(file_path, taxonomy)

        # Sleep for a while after each call
        time.sleep(1)

# %%
# Sample n random rows from the data
file_path = "data/besluitenVlaanderen.json"

def prepare_data(binding):
    # Get the 'sub' value
    sub = binding.get('url', {}).get('value', binding.get('sub', {}).get('value', ''))

    # Get the 'beschrijving' value
    beschrijving = ''
    if 'titel' in binding:
        beschrijving += binding['titel']['value'] + " : "
    beschrijving += binding['beschrijving']['value']
    beschrijving = beschrijving.strip()

    return {
        "text": beschrijving,
        "uri": sub
    }

def process_json_file(file_path, num_skips=0, num_samples=-1):
    errors = 0
    seen_texts = set()
    dataset = []

    # Read the JSON file
    with open(file_path, 'r') as f:
        data = json.load(f)

    bindings = data['results']['bindings']
    random.shuffle(bindings)

    # Process each binding
    for binding in tqdm(bindings[num_skips:num_samples]):
        data_tmp = prepare_data(binding)

        # Skip if this text has already been seen or is empty
        if data_tmp['text'] in seen_texts or not data_tmp['text'].strip():
            errors += 1
            continue

        # Add the text to the set of seen texts
        seen_texts.add(data_tmp['text'])

        dataset.append(data_tmp)

    return dataset, errors

dataset, errors = process_json_file(file_path, num_samples=5000)
# Out:
# 100%|██████████| 5000/5000 [00:00<00:00, 166527.86it/s]

# %%
import random

n = 1  # Number of keywords to select

#processed_keywords = set()

for data in dataset[0:2000]:
    keywords = extract_keywords_agendapunt(data)
    print(f"Keywords: {keywords}")

    # Randomly select n keywords
    #selected_keywords = random.sample(keywords["keywords"], min(n, len(keywords["keywords"])))

    if False:
        selected_keywords = random.sample(keywords["keywords"][:3], min(n, len(keywords["keywords"])))

        for keyword in selected_keywords:
            if keyword not in processed_keywords:
                summary = generate_summary_agendapunten(keyword, 20)
                processed_keywords.add(keyword)
                time.sleep(5)
# Out:
# Keywords: {'keywords': ['ontslag', 'administratief medewerker', 'pensioenleeftijd', 'college']}
# Keywords: {'keywords': ['vergunning', 'Deputatie', 'Limbourg Claire', 'Lindeveldstraat', 'Geraardsbergen', 'kadastraal', 'verkavelen', 'open bebouwing', 'halfopen bebouwing']}
# Keywords: {'keywords': ['college van burgemeester en schepen', '25 mei 2023', 'Basic Fit', 'brandveiligheidsattest B']}
# Keywords: {'keywords': ['Project groenblauwe dooradering', 'participatiemoment', 'communicatie', 'organisatie', 'goedkeuring', '30 mei 2023', '1 juli 2023']}
# Keywords: {'keywords': ['vast bureau', 'financieel beheer', 'OCMW', 'bestelbonnen', 'aanrekeningen', 'vorderingen']}
# Keywords: {'keywords': ['college', 'proces-verbaal', 'toelichting', 'selectiecommissie', 'bevorderingsprocedure', 'voltijdse betrekkingen', 'geschoold arbeid(st)er', 'rein- en ruimdienst', 'niveau D', 'contractueel verband', 'onbepaalde duur']}
# Keywords: {'keywords': ['Overheidsopdracht van leveringen', 'Raamovereenkomst', 'leermateriaal', 'basisonderwijs', 'buitengewoon basisonderwijs', 'DOKO vzw', 'Goedkeuring']}
# Keywords: {'keywords': ['Verdaagd']}
# Keywords: {'keywords': ['gemeenteraad', 'goedkeuring', 'gebruiksovereenkomst', 'gemeente Zandhoven', 'Arktos vzw', 'OverKop-huis', 'Vierselbaan 13', 'JOTH vzw', 'gemeenteraadsbeslissing', '23 januari 2020']}
# Keywords: {'keywords': ['schepencollege', 'aanwervingsprocedure', 'voltijdse functie', 'expert samenleven', 'contractueel dienstverband', 'wervingsreserve', 'selectieprocedure']}
# Keywords: {'keywords': ['Definitieve afhandeling', 'project Krottenbestrijding', 'BSO2', 'Goedkeuring']}
# Keywords: {'keywords': ['Atletiek Bonheiden', 'jaarlijkse veldloop', '06/11/2022', 'college van burgemeester en schepenen', 'tijdelijke verkeersverordening', 'Grote Doelstraat']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'algemeen directeur', 'voorstel', 'evaluatiecriteria', 'overleg']}
# Keywords: {'keywords': ['stilstaan- en parkeerverbod', 'parking 1', 'Sportdreef', 'veegwerken', '13 juni 2023', '8u tot 11u']}
# Keywords: {'keywords': ['Aanvraag', 'stage', 'student', 'Thomas More', 'Goedkeuring']}
# Keywords: {'keywords': ['aanvraag', 'functiewijziging', 'handelszaak', 'beslissing', 'vergunnen']}
# Keywords: {'keywords': ['Renovatie', 'zolder', 'kasteeldomein', 'Bestek', 'raming', 'wijze van gunnen', 'Goedkeuring']}
# Keywords: {'keywords': ['raad', 'consolidatie', 'leningen', 'financiering', 'investeringen', '2021']}
# Keywords: {'keywords': ['aankopen', 'uitleendienst', 'budgetverschuiving', 'goedgekeurd']}
# Keywords: {'keywords': ['goedkeuren', 'gunning', 'toegangsdeuren', 'jeugdclub Jungle']}
# Keywords: {'keywords': ['college', 'goedkeuring', 'ontwerpakte']}
# Keywords: {'keywords': ['corona Covid-19 maatregelen', 'vrijstelling van betaling', 'huur', 'uniforme windschermen', 'parasols', 'terrassen', 'Markt', 'Gentpoortstraat', 'Schutterijstraat', 'Kaaistraat', 'Kalkhofstraat', 'Leiedam', 'crisistijd Covid-19', 'Raad van Bestuur']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'onverhaalbaar stellen', 'openstaande vorderingen', 'belastingen']}
# Keywords: {'keywords': ['factuur', 'automatische inleverbus', 'RFID uitleenbalie', 'bibliotheek filiaal Zingem', 'EKZ Benelux', '38.508,00 € excl BTW']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'onderzoek', 'geldigheid', 'ingediende kandidaturen', 'selectieprocedure', 'functie', 'administratief medewerker', 'Burgerzaken', 'C1-C3', 'voltijds contractueel verband', 'dienst Burgerzaken']}
# Keywords: {'keywords': ['college', 'kandidatuur', 'teamleider Groen', 'C4-C5', 'selectiecommissie']}
# Keywords: {'keywords': ['Rapportage', 'opvolging', 'actiepunten', 'gemeenteraad', '25 oktober 2022', 'Kennisneming']}
# Keywords: {'keywords': ['schepencollege', 'goedkeuring', 'gunning', 'opdracht', 'Raadzaal', 'vernieuwing', 'aanpassing', 'beeld en geluid', 'economisch meest voordelige bieder', 'Bekafun bvba', 'Heilig Hartstraat 23', '8870 Izegem']}
# Keywords: {'keywords': ['omgevingsvergunning', 'meergezinswoning', 'afbraak', 'bestaande bebouwing', 'Moerstraat 14', 'Moerstraat 14A', 'Moerstraat 16', 'OMV_2021170615']}
# Keywords: {'keywords': ['Toetreding', 'aankoopcentrale', 'IOK', 'groepsaankoop', 'Raamovereenkomst', 'hospitalisatieverzekering', 'Goedkeuring']}
# Keywords: {'keywords': ['uitgaande facturen', 'vast bureau', '08/08/2021 tot 22/08/2021', 'bedrag', 'budget 2021']}
# Keywords: {'keywords': ['omgevingsvergunning', 'Aalter', 'Groendreef 7', 'Collegebeslissing', '2022_CBS_01589', 'OMV_2022030832']}
# Keywords: {'keywords': ['geveltuin', 'demoproject', 'Hof van Picardië', "'t Appeltje", 'college van burgemeester en schepenen', 'prijsvraag']}
# Keywords: {'keywords': ['burgemeester', 'toelating', 'Beke 85 - 89', '9950 Lievegem', 'container', 'bestelwagen', 'openbare weg', '3 oktober 2022', '17 oktober 2022']}
# Keywords: {'keywords': ['KAJ Machelen', 'CocktailvsBeer', 'Leihoekstraat', 'Vaartstraat', 'Petegemstraat', 'evenement', 'éénrichtingsverkeer', '2 oktober 2021', '3 oktober 2021']}
# Keywords: {'keywords': ['Rouwverlof', 'Rechtspositieregeling', 'OCMW', 'Aanpassing', 'Goedkeuring']}
# Keywords: {'keywords': ['Dorpsstraat', 'Sint-Aldegondiskerk', 'Deurle', 'paaltjes', 'parkeren', 'kettingen', 'gemeenteraad', 'verlichting', 'bordjes', 'evaluatie', 'alternatieve oplossing']}
# Keywords: {'keywords': ['vast bureau', 'werking', 'activiteiten', 'sociale kruidenier', '2021']}
# Keywords: {'keywords': ['student verzorging', 'contractueel verband', 'voltijdse prestaties', 'woonzorgcentrum De Populier', '475 uur', '1 januari 2022', '31 december 2022']}
# Keywords: {'keywords': ['subsidies 2021', 'vrijwilligerswerking', 'erkende consultatiebureaus', 'Kind en Gezin', 'college']}
# Keywords: {'keywords': ['subsidie', 'kleine en veilige projecten', 'verenigingen', 'gemeenteraad', 'Singelwandelaars', 'Jeugdhuis Rafiki', 'Rochusstars', 'Basket Centrum Grimbergen', 'Sasbikers Humbeek', 'Jeugdraad Grimbergen', 'Ferm Grimbergen', 'S.C.S.G Swimming Club Strombeek Grimbergen']}
# Keywords: {'keywords': ['college', 'proces-verbaal', 'ingebrekestelling', '7 september 2021']}
# Keywords: {'keywords': ['omgevingsvergunning', 'functiewijziging', 'bouwen', 'alleenstaande woning', 'vrijstaand bijgebouw', 'slopen', 'Clevenstraat 10', 'OMV_2022051640']}
# Keywords: {'keywords': ['bestelbonnen', 'goedkeuringslijst', 'vast bureau', 'O/2023/23']}
# Keywords: {'keywords': ['jeugdraad', 'verslag', '31 mei 2023', 'kennisname', 'standpuntbepaling']}
# Keywords: {'keywords': ['Raad voor maatschappelijk welzijn', 'jaarverslag informatieveiligheid 2022', 'veiligheidsplan 2023 - 2025', '15 juni 2023']}
# Keywords: {'keywords': ['vergunning', 'werken', 'nieuw distributienet', 'Fluvius', 'Rijvers', 'Lievegem', '27 januari 2022', '3 februari 2022']}
# Keywords: {'keywords': ['Lokaal dienstencentrum', 'Huishoudelijk reglement', 'Buurtzorgwinkel', 'Goedkeuring']}
# Keywords: {'keywords': ['bronbemaling', 'kelder', 'Bosstraat 3', 'college van burgemeester en schepenen']}
# Keywords: {'keywords': ['schepencollege', 'politieverordening', 'telecominfrastructuur', 'Rijkendalstraat', 'Sint-Amandsstraat', 'RDR Infra', 'Fluvius', 'werken', 'voetpad', 'rijvak', 'parkeerverbod', 'éénrichtingsverkeer', '17 juni 2021', '25 juni 2021']}
# Keywords: {'keywords': ['register', 'bestelaanvragen', 'gemeente', '23 februari', '1 maart 2023']}
# Keywords: {'keywords': ['Aktename', 'opmerkingen']}
# Keywords: {'keywords': ['Aktename', 'aanvraagformulieren', 'evenementen']}
# Keywords: {'keywords': ['Notulen', 'openbare vergadering', 'gemeenteraad', '28 maart 2022', 'Goedkeuring']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'gemeenteraad', 'goedkeuring', 'agentschap Facilitair Bedrijf', 'Vlaamse overheid', 'raamovereenkomst', 'drukwerk', '1 februari 2022', '1 maart 2025']}
# Keywords: {'keywords': ['verlenging', 'tijdelijk politiereglement', 'proefopstelling mobiliteit', 'regio Paddenhoek', 'fietsstraten', 'suggestiestroken', 'onderzoek']}
# Keywords: {'keywords': ['Vacante uren', 'Vaste benoeming', '01 01 2022', 'Goedkeuring', '2021_CBS_00432']}
# Keywords: {'keywords': ['Gemeenteraadscommissies', 'wijziging samenstelling', 'Kennisneming']}
# Keywords: {'keywords': ['omgevingsvergunning', 'Peter Hulselmans', 'Kerkstraat 134', '2022_CBS_01493', 'OV/OP/2022/91']}
# Keywords: {'keywords': ['college', 'ontwerpakte', 'verkoop', 'gemeente']}
# Keywords: {'keywords': ['college', 'inlichtingenformulier', 'procureur des Konings', 'Halle-Vilvoorde', '19 april 2022']}
# Keywords: {'keywords': ['taalklacht', 'tweetalig gebruik', 'bpost Grimbergen', 'Wolvertemsesteenweg 89', 'taalwetgeving', 'schepencollege', '24 januari 2021']}
# Keywords: {'keywords': ['Opdracht afgevaardigde', 'Digipolis', 'Algemene vergadering', 'Bijzondere algemene vergadering', 'Sluiting vereffening', 'Goedkeuring']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'stopzetting', 'project', 'Totaalbeeld', 'digitale en inclusieve klantenbenadering']}
# Keywords: {'keywords': ['juryleden', 'selectiecommissie', 'aanwervingsexamen', 'Theatertechnieker', 'C1-C3']}
# Keywords: {'keywords': ['Stadsmakers', 'Werkwijze geefbibs', '2022', 'Goedkeuring', 'DCHO', 'Antwerpen']}
# Keywords: {'keywords': ['Burgemeester Claeysstraat', '8730 Beernem', 'straat afsluiten', 'signalisatie', 'strapdag', '17 september 2021']}
# Keywords: {'keywords': ['Klacht', 'raadslid Gerald Kindermans', 'gemeenteraadsbeslissing', '23 januari 2023', 'Huurovereenkomst bibliotheek', 'niet vernietiging', 'Kennisneming']}
# Keywords: {'keywords': ['notulen', 'openbare zitting', 'besloten zitting', '18 mei 2015', 'goedkeuring']}
# Keywords: {'keywords': ['Ambtshalve schrapping', 'Goedkeuring', '2021_CBS_01103']}
# Keywords: {'keywords': ['college', 'voorwaardelijk gunstig advies', 'gemeentelijke omgevingsambtenaar', '13 maart 2023', 'aanvraag', 'vergunnen', 'voorwaarden', 'lasten']}
# Keywords: {'keywords': ['Jaarverslag', 'ZorgGroep Zin', 'Kennisneming', '2021_VB_00361']}
# Keywords: {'keywords': ['evaluatie', 'besproken']}
# Keywords: {'keywords': ['college', 'advies', 'gemeentelijke omgevingsambtenaar', 'omgevingsvergunning', 'belasting']}
# Keywords: {'keywords': ['omgevingsvergunning', 'BP Group BVBA', 'industriehal', 'Kinrooi', 'Leuerbroek 2036', 'Ophoven', 'college van burgemeester en schepenen', '12-07-2021']}
# Keywords: {'keywords': ['recht van voorkoop', 'aanvraag']}
# Keywords: {'keywords': ['Bijzonder Onderhandelingscomité', 'Hoog Overlegcomité', 'verplaatsen', 'agenda', '14/02/2023']}
# Keywords: {'keywords': ['Zitting', '20 06 2023', 'PH.3', 'Wijziging Retributiereglement', 'Materiaal', 'Toevoegen', 'Prijszetting', 'College', 'Uitleendienst']}
# Keywords: {'keywords': ['straatoptreden', 'Kon.Muziekmaatshappij St.Cecilia Koolskamp', '26 november 2022']}
# Keywords: {'keywords': ['tijdelijke verordening', 'wegverkeer', 'Dahliastraat 3', 'Aarschot', 'blokkeren', 'doorlopend verkeer', 'vrachtwagen']}
# Keywords: {'keywords': ['Interpellatie', 'raadslid Karel Noppe', 'Prijzen', 'recreatiedomein De Ster']}
# Keywords: {'keywords': ['Switch to Move', 'Switch Jump', 'dienst vrije tijd', 'lagere school', 'sportactiviteiten', 'Sportschuur', 'schooljaar 2023-2024', 'inschrijvingsgeld', 'Netwerk Lokaal Sportbeleid', 'gemeente', 'busvervoer', 'proeflessen', 'verzekering', 'exploitatiebudget']}
# Keywords: {'keywords': ['college', 'aanwervingsprocedure', 'functie', 'deeltijds toezichter', 'overeenkomst van onbepaalde duur']}
# Keywords: {'keywords': ['burgemeester', 'machtiging', 'verkopen', 'verstrekken', 'schenken', 'gegiste dranken', 'sterke dranken', 'KLJ Wingene', 'Full Pull Weekend', '8 juli 2022', '10 juli 2022', 'De Ketelaere', 'Rozendalestraat', 'Wingene']}
# Keywords: {'keywords': ['gemeenteraad', 'reglement', 'ondersteuning', 'kinderopvanginitiatieven']}
# Keywords: {'keywords': ['Feestcomité Donkerstraat', 'buurtfeest', 'Bleukstraat 11', 'Bonheiden', 'zaterdag 10/09/2022']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'toelating', 'reclameborden', 'fuif', "Black 'N White", '04/03/2023']}
# Keywords: {'keywords': ['Welzijnskansen', 'Fonds voor Europese hulp aan de meest behoeftigen', 'FEAD', 'Partnerschapsovereenkomst', 'noodhulporganisatie', 'Ondertekening', 'Goedkeuring']}
# Keywords: {'keywords': ['personenlijst', 'bevolkingsregister', 'intern gebruik', 'doelgroepenbeleid', 'Team Jeugd', '12-15 jarigen', 'Wingene', 'informatieveiligheidsbeleid', 'bewaartermijn']}
# Keywords: {'keywords': ['Aanvullend reglement', 'politie van het wegverkeer', 'parkeer- en stilstaanverbod', 'Rode Dreef']}
# Keywords: {'keywords': ['restauratiepremie', 'werken aan het dak', 'goten', 'Pastorie Sint-Willibrordusparochie', 'Collegebeslissing']}
# Keywords: {'keywords': ['Ontwerp', 'renovatie', 'stationsgebouw']}
# Keywords: {'keywords': ['behandeling', 'agendapunt', 'uitgesteld', 'volgende vergadering']}
# Keywords: {'keywords': ['De Stadsfabriekjes', 'Stopzetting', 'GOUDSKOOL', 'Molenstraat', 'terugvordering', 'Goedkeuring']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'melding', 'tijdelijke bronbemaling', 'zwembad', 'Noordabeelstraat 77', '8830 Hooglede', 'kadastrale ligging', 'afdeling 2 sectie D nr. 247C']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'jury', 'aanwervingsexamen', 'deskundige administratie infrastructuur']}
# Keywords: {'keywords': ['college', 'uitbetaling', '7.500 euro', 'Parochiaal Verenigingsleven', 'Merendree vzw', 'saldo 2020', 'voorschot 2021']}
# Keywords: {'keywords': ['jaarrekening 2021', 'stad Deinze', 'gemeenteraad', '21 juni 2022', 'college']}
# Keywords: {'keywords': ['vorderingsstaat 3', 'Mourik nv', 'Groenendaallaan 399', '2030 Antwerpen', 'Afvalverwijdering', 'Afvalverwerking', 'Voortstraat 14', 'Bukenstraat 76']}
# Keywords: {'keywords': ['zorgkrediet', 'vastbenoemde bijzondere leermeester', 'Rooms Katholieke godsdienst', '1 september 2021', '30 juni 2022']}
# Keywords: {'keywords': ['college', 'notulen', 'vorige zitting']}
# Keywords: {'keywords': ['tijdelijke verordening', 'wegverkeer', 'Geetsstraat', 'Aarschot', 'Graafwerk', 'Proximuskabel', 'FTTH Project']}
# Keywords: {'keywords': ['concessie', 'urnenkelder', 'begraafplaats', 'Lovendegem']}
# Keywords: {'keywords': ['Jerome Vandemaele', '100-jarige', 'huldigt', 'college van burgemeester en schepenen', '29 januari 2023']}
# Keywords: {'keywords': ['kandidatenlijst', 'zorgkundige', 'IFIC 11 (bis)', 'contractuele betrekkingen', 'langdurig afwezigen', 'aanwerving']}
# Keywords: {'keywords': ['kennis']}
# Keywords: {'keywords': ['college', 'omgevingsvergunning', 'voorwaarden']}
# Keywords: {'keywords': ['college', 'omgevingsvergunning']}
# Keywords: {'keywords': ['Proximus', 'werkzaamheden', 'gemeente', 'toelating', 'eind 2022']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'offerte', 'Brebuild Algemeen Bouwbedrijf NV', 'Schouwkensstraat 10', '2030 Antwerpen', 'herstelling van het dak', '€ 2.518,66', 'exclusief btw']}
# Keywords: {'keywords': ['Besluit Burgemeester', 'Tijdelijk verkeersreglement', 'verboden toegang', 'bestuurders van voertuigen', 'vervoer van zaken', 'Hansbeke', 'schooldag', 'middagpauzes', 'basisschool Sint-Paulus']}
# Keywords: {'keywords': ['Districtsraad', 'Mededeling', 'punten dagorde', 'zitting', '15 november 2021', 'Kennisneming']}
# Keywords: {'keywords': ['Notarisinfo', 'artikel 5.2.2', '2022/00004/SPLITSING', 'Boomsteeg 43-45', 'Goedkeuring']}
# Keywords: {'keywords': ['Wandelclub Scheldestappers', 'Sint-Bavotocht', 'Kerkplein 12', '11 december 2022', 'publiciteitsborden', 'bewegwijzering', 'open lucht', 'gemeentewegen', 'lokale politie', 'brandweer']}
# Keywords: {'keywords': ['gemeenteraad', 'Vlaamse Regering', 'woonmaatschappij', 'doelstellingen', 'gemeente', 'erkenningsaanvraag', 'SWAL']}
# Keywords: {'keywords': ['Sector cultuur en vrije tijd', 'Bibliotheek', 'Vrijwillig ontslag', 'tijdelijk bibliotheekassistent', 'Lokeren']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'gratis app', 'multibel', 'alarmeringsoplossing']}
# Keywords: {'keywords': ['omgevingsvergunning', 'deputatie', 'provincie Vlaams-Brabant', 'regularisatie', 'gebouw H', 'Temselaan 100', 'Grimbergen', 'Vlaamse Regering', 'omgevingsvergunningsdecreet', 'beroep', 'beveiligde zending']}
# Keywords: {'keywords': ['college', 'oninvorderbare bedragen']}
# Keywords: {'keywords': ['omgevingsvergunning', 'Jan DE BOELPAEP', 'Julchen VAN MALDEREN', 'halfopen eengezinswoning', 'Mechelstraat 63A', '1851 Grimbergen', 'kadastraal gekend', 'beroep instellen', 'Omgevingsloket', 'deputatie van de provincie Vlaams-Brabant', 'Provincieplein 1', '3000 Leuven']}
# Keywords: {'keywords': ['college', 'mandaten', 'lijst']}
# Keywords: {'keywords': ['ANB', 'bestuurlijke maatregelen', 'schending', 'bosdecreet']}
# Keywords: {'keywords': ['deeltijds medewerker', 'bar en maaltijden', 'contractueel dienstverband', 'arbeidsovereenkomst', 'bepaalde tijd', '8 september 2022', '7 december 2022']}
# Keywords: {'keywords': ['Collegebeslissing', 'goedkeuring', 'gunning', 'opdracht', 'Vormingen', 'inspiratienamiddag', 'diversiteit']}
# Keywords: {'keywords': ['college', 'vraag', 'elektriciteit', 'water', 'circus', 'grasveld', 'Gemeentepunt', 'Heirbaan 73', '8570 Anzegem', 'voorjaar 2022', 'aftappunt', 'betaling']}
# Keywords: {'keywords': ['Nihil']}
# Keywords: {'keywords': ['Oost-Vlaanderen', 'week van de markt', 'Provincie Oost-Vlaanderen', 'Nationale Groepering Ambulante Handel', 'lokale besturen', 'oktober 2020']}
# Keywords: {'keywords': ['Handhaving', 'Ruimtelijke Ordening', 'Prioriteitenkader', 'Omgeving']}
# Keywords: {'keywords': ['schepencollege', 'tewerkstelling', 'personeelsleden', 'diensten', 'activiteiten', 'COVID-19']}
# Keywords: {'keywords': ['Afterparty Sfinks', 'Wattan', 'Jozef Hoegaerts', 'burgemeester en schepenen', '30 juli 2023', '31 juli 2023', '95 dB(A)', 'evenementenloket', 'oordopjes', 'omwonenden']}
# Keywords: {'keywords': ['plaatsbezoek', 'milieudienst', 'heraanplanting', 'college', 'waarborg']}
# Keywords: {'keywords': ['Buitenspeeldag', 'woensdagnamiddag', '20 april 2022', 'college van burgemeester en schepenen', 'deelnamevoorwaarden', 'Goedgekeurd']}
# Keywords: {'keywords': ['Advies', 'rekening 2021', 'kerkfabriek Sint-Barbara', 'Tessenderlo', 'Berg']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'vorderingsstaat', 'goedkeuring']}
# Keywords: {'keywords': ['Aanleg verharde parking', 'Rodekruisstraat', 'Lommel', 'Weigering', '2022_CBS_00914', '2021/281-01/OMV']}
# Keywords: {'keywords': ['RMW', 'Wonen', 'vast bureau', 'Woonhaven Antwerpen', 'buitengewone algemene vergadering', 'mandaat', 'vertegenwoordiging', 'goedkeuring', 'bekrachtiging']}
# Keywords: {'keywords': ['college', 'gunstig', 'stedenbouwkundig attest']}
# Keywords: {'keywords': ['Ruimen van baangrachten', 'Verlenging 3', 'Goedkeuring', '2022_CBS_00558', 'Lokeren']}
# Keywords: {'keywords': ['Triatlon Lievegem', 'evenement', 'college van burgemeester en schepenen', '15 mei 2021']}
# Keywords: {'keywords': ['gemeenteraad', 'notulen', 'zitting', '22 februari 2022']}
# Keywords: {'keywords': ['college', 'aanvraag', 'verlof', 'verminderde prestaties']}
# Keywords: {'keywords': ['Protestantse Johanneskerk', 'Budget dienstjaar 2023', 'wijziging nr. 1', 'meerjarenplan 2020-2025', 'Goedkeuring']}
# Keywords: {'keywords': ['vast bureau', 'selectieverloop', 'samenstelling', 'selectiecommissie']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'motie', 'agenderen', 'gemeenteraad']}
# Keywords: {'keywords': ['bestek', 'raming', 'opdracht', 'lastvoorwaarden', 'algemene uitvoeringsregels', 'overheidsopdrachten', 'aannemingen', 'werken', 'leveringen', 'diensten', '165.382,80 euro', 'goedgekeurd']}
# Keywords: {'keywords': ['gemeente Affligem', 'Vlaamse overheid', 'subsidie', 'Gemeente zonder Gemeentehuis', 'beslissing', 'e-mail', 'college van burgemeester en schepenen']}
# Keywords: {'keywords': ['College van Burgemeester en Schepenen', 'aanrekeningen', 'goedkeuren', '2.500,00 EUR', 'exclusief BTW']}
# Keywords: {'keywords': ['inwoner', 'gemeente', 'vreemdelingenregister', 'geschrapt']}
# Keywords: {'keywords': ['Contract', 'lening', 'financiering', 'investeringsprojecten', 'stad', 'Goedkeuring']}
# Keywords: {'keywords': ['schepencollege', 'goedkeuring', 'vorderingsstaat', 'opdracht']}
# Keywords: {'keywords': ['Notulen', 'vorige zitting', 'Goedkeuring', '2022_CBS_01311']}
# Keywords: {'keywords': ['Dentergem', 'college', 'toelating', 'organisatie', 'evenement', 'Toeters en taarten', '1.05.2022', 'JOC']}
# Keywords: {'keywords': ['omgevingsvergunning', 'Lars Nuyts', 'Schotelven 74', 'OV/OP/2023/37', 'Kennisneming']}
# Keywords: {'keywords': ['Youca Action Day 2022', 'bibliotheek van Grobbendonk', 'GROS', 'Team HRM & Secretariaat', 'Team Financieel Management', '20 oktober 2021']}
# Keywords: {'keywords': ['Kerkfabriek Sint-Anna Mechelen-Bovelingen', 'rekening 2022', 'Advies']}
# Keywords: {'keywords': ['Schepencollege', 'toestemming', 'concessie', '50 jaar', 'urnekelder']}
# Keywords: {'keywords': ['college', 'politiereglement', 'buurtfeest', 'Fonteinplein', '02-07-2023']}
# Keywords: {'keywords': ['tijdelijke leerkracht', 'voltijdse leerkracht', 'Gemeentelijke Basisschool Zemst-Laar De Pimpernel', 'schooljaar 2022-2023', 'college']}
# Keywords: {'keywords': ['Fluvius', 'bezwaar', 'aanslagbiljet', 'stad Bree', 'belasting']}
# Keywords: {'keywords': ['Anzegem', 'communicatie', 'vrijwilligers', 'foto-opdrachten', 'gemeentelijke diensten']}
# Keywords: {'keywords': ['omgevingsvergunning', 'slopen', 'bouwen', 'veranda', 'Ter Heide 8', 'OMV_2021137670']}
# Keywords: {'keywords': ['notulen', 'vergadering', '19 juni 2023', 'goedgekeurd']}
# Keywords: {'keywords': ['omgevingsvergunning', 'Gewestelijk Omgevingsambtenaar', 'Vlaamse Milieumaatschappij', 'college']}
# Keywords: {'keywords': ['concessie', '10 jaar', 'begraafplaats', 'naamplaatje']}
# Keywords: {'keywords': ['college', 'aanstelling', 'vrijwilligers']}
# Keywords: {'keywords': ['opname van de vergadering', 'website van de gemeente', 'tijdstip 1:52:10']}
# Keywords: {'keywords': ['Kennisname']}
# Keywords: {'keywords': ['Aanpassing schooluren', 'GBS Op Dreef', '1-9-2020', 'beslissing']}
# Keywords: {'keywords': ['omgevingsvergunning', 'Heikant', 'aanleg wegenis', 'bronbemaling', 'Goedkeuring']}
# Keywords: {'keywords': ['distributienet', 'Kestelstraat', 'Fiberklaar', 'Collegebeslissing', 'uitbreiden']}
# Keywords: {'keywords': ['Opdrachthoudende Vereniging Schulens Meer', 'OSM', 'agenda', 'algemene vergadering', '30 juni 2021', 'Goedkeuring']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'aanvraag', 'personenlijst', 'bevolkingsregister', 'scholengemeenschap Driespan', 'geboortejaar 2020']}
# Keywords: {'keywords': ['Definitieve vaststelling', 'verlegging', 'buurtweg 90', 'Kruisstraat', 'Goedkeuring']}
# Keywords: {'keywords': ['college', 'bestelbonnen', 'goedkeuring']}
# Keywords: {'keywords': ['Gemeenteraad', 'Mededeling', '3 oktober', '2022_CBS_00983']}
# Keywords: {'keywords': ['Maand van de Markt', 'april 2022', 'Provincie Oost-Vlaanderen', 'college van burgemeester en schepenen']}
# Keywords: {'keywords': ['betaalbaarstellingen', 'goedkeuring', 'college', 'vast bureau']}
# Keywords: {'keywords': ['schepencollege', 'bestelaanvragen', 'bestelbonnen', '760 t/m 785']}
# Keywords: {'keywords': ['renteloze lening', 'AGB Tielt', 'stad Tielt', 'meerjarenplan 2020-2025', 'investeringen', 'overeenkomst', 'gemeenteraad', 'bedrag', 'leningen', 'afschrijvingsritme']}
# Keywords: {'keywords': ['college', 'politieverordening', 'wielerwedstrijd', 'Gooikse Pijl', '17 september 2023']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'aanpassing', 'huishoudelijk reglement', 'gebruik', 'gemeentelijke culturele infrastructuur', 'coronaproof', 'hoogdringendheid', '6 juli 2021']}
# Keywords: {'keywords': ['vast bureau', 'beslissingen', 'dagelijks bestuur', 'algemeen directeur', 'delegatie', 'raad']}
# Keywords: {'keywords': ['verkeersmaatregel', 'parkeerverbod', 'Molenbeemden', 'Ringlaan', 'college van burgemeester en schepenen']}
# Keywords: {'keywords': ['strategisch meerjarenplan', 'SMJP', 'gemeente', 'OCMW', 'jaarrekeningen 2021', 'ramingen', 'verwachtingen', 'OCMW-raad', 'uitgaven', 'ontvangsten', '2020 - 2025']}
# Keywords: {'keywords': ['betaalbaarstelling', '11-2023', 'algemeen directeur']}
# Keywords: {'keywords': ['Budget 2023', 'kerkfabriek Sint-Laurentius', 'Sint-Pieter in Banden', 'Kennisgeving']}
# Keywords: {'keywords': ['goedkeuring', 'algemene vergadering', 'jaarverslag', 'jaarrekening', 'bestuurders', 'financieel directeur', 'revisor', 'bedrijfsrevisor-commissaris', 'DVV Midwest', '2020', '2021 - 2023']}
# Keywords: {'keywords': ['Kandidaten', 'vacature', 'bibliothecaris', 'Goedkeuring']}
# Keywords: {'keywords': ['principieel akkoord', 'overleg', 'gebruikers', 'OC']}
# Keywords: {'keywords': ['gemeenteraad', 'aanvullend verkeersreglement', 'parkeerplaats', 'personen met een handicap', 'Warande']}
# Keywords: {'keywords': ['college', 'toelating']}
# Keywords: {'keywords': ['gebruiksovereenkomst', 'Meulenbroekenlaan', 'parkeerplaatsen', 'laadplaatsen', 'laadinfrastructuur', "deelauto's", 'deelfietsen']}
# Keywords: {'keywords': ['deeltijdse coördinator', 'Team Kind', 'B1-B3', 'contractueel dienstverband', 'onbepaalde duur']}
# Keywords: {'keywords': ['college', 'rapport', 'beslissingen', 'algemeen directeur', 'dagelijks personeelsbeheer']}
# Keywords: {'keywords': ['Tijdelijke aanstelling', 'leerkracht', 'bepaalde duur', 'gemeentelijke sportbasisschool De Oester', 'Strijlandstraat 40', '1755 Gooik', 'kleuteronderwijzeres', '6 lestijden', 'werkingsbudget']}
# Keywords: {'keywords': ['vergunning', 'werken', 'drinkwateraansluiting', 'Farys', 'Schachterijstraat 10', '9920 Lievegem', '16 september 2022', '22 september 2022']}
# Keywords: {'keywords': ['CBS', '14 juni 2023', 'MAT', '3 mei 2023', 'college van burgemeester en schepenen', 'verslag', 'besluit']}
# Keywords: {'keywords': ['beroep', 'gemeentelijk leegstandsregister', 'woning', 'Nieuwstraat 32', '9450 Haaltert', 'kadastraal gekend', '41010B1076/00L000', 'college']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'ondertekening', 'intentieverklaring', 'Strategisch project', 'Regionale onthardingsstrategie']}
# Keywords: {'keywords': ['budgethouder', 'dossierbeheerder', 'factuur', 'MIELE BELGIE PROFESSIONAL', 'HERSTELLING WASMACHINE', '218.28 euro', '12.08.2022']}
# Keywords: {'keywords': ['Chape site', 'Klaverstraat', 'Koolskamp', 'opgeleverd']}
# Keywords: {'keywords': ['schepencollege', 'interne personeelsmobiliteit', 'voltijdse functie', 'vakman', 'koermeester', 'contractueel dienstverband', 'afdeling Ruimte', 'Magazijn', 'selectieprocedure']}
# Keywords: {'keywords': ['Samenwerkingsovereenkomst', 'Wham Office', 'street art', 'publieke ruimte', 'goedkeuring']}
# Keywords: {'keywords': ['gemeenteraad', 'advies', 'jaarrekeningen', 'kerkfabrieken', 'gemeente']}
# Keywords: {'keywords': ['omgevingsvergunning', 'Ann BROCHE', 'vrijstaande eengezinswoning', 'Beigemsesteenweg 109', '1850 Grimbergen', 'beroep instellen', 'deputatie van de provincie Vlaams-Brabant', 'Omgevingsloket', 'Provincieplein 1', '3000 Leuven']}
# Keywords: {'keywords': ['huurovereenkomst', 'Koninklijke Rupel Boom Football Club', 'Gemeentelijk Voetbalterrein A', 'Boom Acacialaan 45+', 'college van burgemeester en schepenen']}
# Keywords: {'keywords': ['raad voor maatschappelijk welzijn', 'ondertekening', 'Overeenkomst', 'ouderenbehoefteonderzoek', 'Londerzeel']}
# Keywords: {'keywords': ['voorlopige vaststelling', 'ontwerp van rooilijn', 'Reeweg', 'Goedkeuring']}
# Keywords: {'keywords': ['hernieuwing concessie', 'centrale begraafplaats', 'Zevergem']}
# Keywords: {'keywords': ['nutswerken', 'Akkerrand', '25 oktober', '3 november']}
# Keywords: {'keywords': ['grafisch plan', 'buurtweg 34', 'Elewijt', 'gemeenteweg', 'gemeenteraad', 'meer-/minwaarde', 'landmeter-expert Bruno Mertens', 'college', 'decreet van 3 mei 2019', 'gemeentewegen']}
# Keywords: {'keywords': ['Gaselwest', 'Notulen', 'Raad van Bestuur', '15.09.2021']}
# Keywords: {'keywords': ['opbrengsten', '1 juni 2023', 'goedgekeurd']}
# Keywords: {'keywords': ['Vrijwillig ontslag', 'statutair personeelslid', 'ontslagdatum', 'Goedkeuring', 'OCMWVB']}
# Keywords: {'keywords': ['Vzw Regionaal Landschap Haspengouw en Voeren', 'aanstelling', 'stemgerechtigd lid', 'plaatsvervanger', 'Algemene vergaderingen', 'Goedkeuring']}
# Keywords: {'keywords': ['Aanvraag vergunning', 'inname openbaar domein', 'Kerkstraat 16b', '3920 Lommel', '05.07.2021', 'Goedkeuring']}
# Keywords: {'keywords': ['Besluiten', 'algemeen directeur', 'Kennisneming', '2023_CBS_00439', 'Arendonk']}
# Keywords: {'keywords': ['verlegging', 'sentier 26', 'Zwartenhoekstraat', 'Dutselaar', 'Goedkeuring']}
# Keywords: {'keywords': ['notulen', 'zitting', '26 april 2021', 'goedkeuring', '2021_PL_00016']}
# Keywords: {'keywords': ['vast bureau', 'verslagen', 'zitting', '8 september 2022']}
# Keywords: {'keywords': ['pensioenaanvraag', 'technisch assistent', 'geschenkcheques', 'college van burgemeester en schepenen', '1 mei 2023']}
# Keywords: {'keywords': ['privatieve ingebruikname', 'openbaar domein', 'stelling', 'dak vervangen', 'Dorpsstraat 35', 'Dorpsstraat 33A', 'oppervlakte: 27 m²', 'periode: 18 november 2022 tot 02 december 2022', 'signalisatie', 'vrije doorgang', 'schade aan openbaar domein', 'retributie: € 101,25']}
# Keywords: {'keywords': ['algemene vergadering', 'Gemeentelijk Extern Verzelfstandigd Agentschap', 'vzw Berentrode', 'gemeenteraad', 'agenda', 'begrotingswijziging 2021', 'begroting 2022', 'investeringen', 'sportpromotie', 'zomersportkampen']}
# Keywords: {'keywords': ['Smoefelroute', 'Jong Vld', 'Koekelare', '6 augustus 2023']}
# Keywords: {'keywords': ['Zitting', '26 juni 2023', 'Rechtzetting', 'aanrekening', 'standplaats', 'ambulante handel', 'kippenkraam', 'Mollem', 'Pascal Raedemaeker', 'belasting', 'privaat ingebruiknemen', 'openbaar domein', 'foutieve facturatie 2022']}
# Keywords: {'keywords': ['tijdelijk politiereglement', 'sportdagen', 'verkeersweek', 'Basisschool De Kiem', 'skatepark', 'sporthal']}
# Keywords: {'keywords': ['CAW Boom-Mechelen-Lier', 'Housing First', 'wooneenheid', 'begeleidingsaanbod']}
# Keywords: {'keywords': ['ontslag', 'technisch medewerker', 'groendienst', 'college van burgemeester en schepenen', 'contractueel goed']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'toelating', 'signalisatie', 'openbare weg']}
# Keywords: {'keywords': ['Delegatie van bevoegdheden', 'overheidsopdrachten', '2021', 'Herentals']}
# Keywords: {'keywords': ['akte', 'melding']}
# Keywords: {'keywords': ['college', 'agenda', 'overleg', '20.10.2021']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'financieel directeur', 'loonkost', '2de kwartaal 2021', 'ter beschikking gesteld personeel', 'Hartje Hageland']}
# Keywords: {'keywords': ['college van Burgemeester en Schepenen', 'deelname', 'goedkeuring']}
# Keywords: {'keywords': ['Ambtshalve afvoering', 'vreemdelingenregister']}
# Keywords: {'keywords': ['adviseur woonkwaliteit', 'WoonWinkel West', 'woningcontroleur', 'woonkwaliteit', 'onderzoeker', 'plaatsbezoeken', 'controles', 'inventarisatie', 'leegstaande woningen', 'verwaarloosde woningen', 'gebouwen']}
# Keywords: {'keywords': ['schepencollege', 'Groep Intro', 'vrijwilliger', 'vrijwilligersvergoeding', 'meisjeswerking', 'Allemanslokaal', 'Strombeek-Bever']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'voorwaardelijke omgevingsvergunning', 'aanvraag O/2022/3']}
# Keywords: {'keywords': ['rechtsbijstand', 'aanvraag', 'goedkeuring', '2022_CBS_01523']}
# Keywords: {'keywords': ['college', 'beslissingen', 'algemeen directeur']}
# Keywords: {'keywords': ['verjaardagkaart 80-jarigen', '80-jarige inwoners', 'verjaardagskaart', 'Ter Borre', 'senioren', 'noden detecteren', 'opvolgen']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'notulen', 'zitting', '19 augustus 2022']}
# Keywords: {'keywords': ['omgevingsvergunning', 'vrijstaande eengezinswoning', 'verhardingen', 'oprit', 'tuinhuis', 'terras', 'Yvonne Dewinterstraat 3', 'college van burgemeester en schepenen']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'gemeentelijke omgevingsambtenaar', 'omgevingsvergunning', 'belasting']}
# Keywords: {'keywords': ['college', 'administratief medewerker', 'verlof', 'verminderde prestaties', 'ziekte', '1 februari 2023', '31 maart 2023', '18/36']}
# Keywords: {'keywords': ['schepencollege', 'politieverordening', 'BROEDERS & CO', 'Fluvius', 'Brusselsesteenweg', 'werkput', 'verkeer', 'voorrangsregeling', '21 december 2022', '23 december 2022']}
# Keywords: {'keywords': ['huwelijksfeest', '01/07/2023', 'weiland', 'Moerheide 81']}
# Keywords: {'keywords': ['vergunning', 'werken', 'wachtbuis', 'CCTV paal', 'gemeente Lievegem', 'Den Boer 15', '9930 Lievegem', '21 augustus 2023', '1 september 2023', '3 juli 2023', '14 juli 2023']}
# Keywords: {'keywords': ['college', 'besluit', 'burgemeester', 'tijdelijke terras', 'hELLO concept store', '20 mei 2021', '21 mei 2021', '31 oktober 2021']}
# Keywords: {'keywords': ['conformiteitsattest', 'waarschuwingsprocedure', 'Overpoort 64', '9500 Geraardsbergen']}
# Keywords: {'keywords': ['tijdelijke grafconcessie', '50 jaar', '13/06/2072', 'gemeentelijke begraafplaats', 'Zingem']}
# Keywords: {'keywords': ['schepencollege', 'wervingsreserve', 'afdelingshoofd', 'Interne organisatie', 'A5a-A5b']}
# Keywords: {'keywords': ['Femma', 'Jubileum', '75-jarig bestaan', 'Besluit', 'Zitting', '17 05 2023']}
# Keywords: {'keywords': ["Jeugdhuis 't Molentje", 'Vrouwenavond en afterparty', '17 september 2021', 'evenement', 'burgemeester', 'toelating']}
# Keywords: {'keywords': ['Stedelijke straatnamencommissie', 'wijziging samenstelling', 'goedkeuring']}
# Keywords: {'keywords': ['schepencollege', 'goedkeuring', 'gunning', 'opdracht', 'Begraafplaats Pittem', 'aankoop', 'opslagcontainer', 'economisch meest voordelige bieder', 'Container Factory', 'Kamperstraat 25', '9630 Zwalm']}
# Keywords: {'keywords': ['gemeenteraad', 'gemeentelijke communicatie', 'sensibiliseren', 'cybercriminaliteit']}
# Keywords: {'keywords': ['Disponibiliteit', 'Beslissing', 'zwerfvuilambtenaar', 'statutair verband', 'Goedkeuring']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'opschorting', 'dinsdagmarktabonnement', 'marktkramer', '1 februari 2022', '22 februari 2022']}
# Keywords: {'keywords': ['uitslag', 'proeven', 'aanwervingsprocedure', 'Kinderbegeleider', 'Buitenschoolse Kinderopvang', 'halftijds', 'niveau IFIC', 'categorie 200', 'contractueel verband']}
# Keywords: {'keywords': ['Fluvius', 'wijziging uurregeling', 'avondregime', 'openbare verlichting', 'goedkeuring']}
# Keywords: {'keywords': ['Zomer in de Fauteuil', 'Organiseren', 'vrijdag 30.06 t.e.m. zondag 03.09.2023']}
# Keywords: {'keywords': ['Tijdelijke politieverordening', 'burgemeester', 'verbod', 'halloween-rondgangen', 'coronavirus', 'COVID-19', '28 oktober 2020', 'Bekrachtiging']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'bezwaarschrift', 'ontvankelijk', 'ongegrond']}
# Keywords: {'keywords': ['Amendement', 'raadslid', 'Tom De Meester', 'belasting', 'inname openbaar domein', 'handelszaken']}
# Keywords: {'keywords': ['klokkenluidersregeling', 'vast bureau', 'arbeidsreglement', 'raad voor maatschappelijk welzijn', 'bijzonder onderhandelings- en hoog overlegcomité', 'gemeente- en OCMW-personeel', 'Decreet Lokaal Bestuur', 'Bestuursdecreet', 'gemeentelijke website']}
# Keywords: {'keywords': ['overeenkomst', 'opvang', 'rondzwervende dieren', 'gemeentebestuur', 'Oostrozebeke', 'V.Z.W. Dierenasiel regio Roeselare']}
# Keywords: {'keywords': ['voltijdse deskundige', 'Omgeving', 'Milieu', 'Klimaat', 'Duurzaamheid', 'contractueel dienstverband', 'onbepaalde duur', 'B1-B3']}
# Keywords: {'keywords': ['Zitting', '26 juni 2023', 'Besluit', 'Ambtelijke schrapping', 'privéadres', 'Goedgekeurd']}
# Keywords: {'keywords': ['leerkracht', 'zang', 'viool']}
# Keywords: {'keywords': ['Nieuwe fractieleider', 'fractie', 'Groen', 'Open Vld']}
# Keywords: {'keywords': ['Vertegenwoordiging', 'EcoWerf', 'Algemene vergadering', '22 juni 2022', 'Goedkeuring']}
# Keywords: {'keywords': ['Autonoom Gemeentebedrijf van Puurs-Sint-Amands', 'huishoudelijk reglement', 'culturele infrastructuur', 'jeugdinfrastructuur', 'sportinfrastructuur', 'Brede School Gebouw', 'cc Binder', 'kunstenaars', 'artiesten', 'makersplaatsen', 'administratieve vereenvoudiging', 'waarborg', 'reservatie-opties', 'productfiches', 'badges', 'ticketservice', 'DJ ruimte', 'Joc WIJland', 'seizoensreservaties', 'gemeenteraad']}
# Keywords: {'keywords': ['concessie', '30 jaar', 'columbarium', 'kerkhof', 'Steenokkerzeel', '2 personen']}
# Keywords: {'keywords': ['Buitenspeeldag', 'spel- en sportactiviteiten', 'grasveld', 'bibliotheek van Kampenhout', 'Tritsstraat 5', 'college van burgemeester en schepenen', 'team vrije tijd']}
# Keywords: {'keywords': ['vergadering', 'unaniem', 'agendapunt', 'verdagen', 'gemeenteraad']}
# Keywords: {'keywords': ['Sector burgerzaken', 'welzijn', 'onderwijs', 'Dienst burgerzaken', 'tijdelijk administratief medewerker', 'studentenovereenkomst', '2021_CBS_01615']}
# Keywords: {'keywords': ['Beleid en Dienstverlening', 'Kerkfabriek St. Clemens', 'Notulen', '18 april 2023', 'college van burgemeester en schepenen']}
# Keywords: {'keywords': ['college', 'goedkeuring', 'aanvragen', 'kermisuitbaters', 'standplaats', 'Sint-Germanuskermis', '6, 7 en 8 augustus 2022', 'Egem']}
# Keywords: {'keywords': ['Jaarrekening 2020', 'gemeente Tessenderlo', 'OCMW Tessenderlo', 'Goedkeuring']}
# Keywords: {'keywords': ['factuur', 'promofilm', 'Belgisch Kampioenschap Judo', 'Tielt']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'VMM', 'actieplan', 'subsidiedossiers', 'Vlaamse codex overheidsfinanciën']}
# Keywords: {'keywords': ['workshops', 'Koken met Atelier22', 'Goedkeuring', '2023_CBS_00811']}
# Keywords: {'keywords': ['ANB202153', 'KVE', 'Wilde Heide', 'Kapmachtiging', 'Kennisneming']}
# Keywords: {'keywords': ['2022_CBS_00832', 'Memoranda', 'Kennisneming']}
# Keywords: {'keywords': ['Goedkeuring', 'verslag', 'vorige vergadering', '23 september 2021', 'CBS', 'Beringen']}
# Keywords: {'keywords': ['ecologisch onderhoud', 'openbare wegen', 'Lievegem', 'dienstjaar 2023', 'Mirto vzw', 'Industrielaan 40', '9900 Eeklo']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'toestemming', 'ecologisch vellen', 'bomen', 'Vliekaertweg']}
# Keywords: {'keywords': ['Collegebeslissing', 'aanvraag tot erkenning', 'vereniging', 'Just Dive', '2022_CBS_04110']}
# Keywords: {'keywords': ['openbare bibliotheek', 'nieuw geautomatiseerd bibliotheeksysteem', 'samenwerking', 'Boomse bib', 'Rupelbib', 'Rumst', 'IVEBICA', 'samenwerkingsverband 1', 'lidgeld', 'inschrijven', 'gemeenteraad']}
# Keywords: {'keywords': ['OCMW', 'landbouwgronden', 'Onderhandse verkoop', 'Agentschap voor Natuur en Bos', 'ANB', 'Goedkeuring']}
# Keywords: {'keywords': ['Goedkeuring', 'verleend']}
# Keywords: {'keywords': ['budgethouder', 'dossierbeheerder', 'factuurnr. 5600020085', 'Dormakaba', '308,55 euro', 'Herstelling toegangsmechanisme', 'inkomdeur', 'Woonzorgcentrum', 'brand', '22/07/2022']}
# Keywords: {'keywords': ['2023_CBS_00948', 'Wedstrijd', 'motorvoertuigen', 'Kennisneming']}
# Keywords: {'keywords': ['raad voor maatschappelijk welzijn', 'overeenkomst', 'lokaal AC07', '1 juni 2021']}
# Keywords: {'keywords': ['vrijstelling', 'aanslagjaren 2022 en 2023', 'belasting', 'leegstand', 'verwaarlozing', 'bedrijfsruimten', 'Polderstraat 3']}
# Keywords: {'keywords': ['gemeenteraad', 'agendapunten', '11 juni 2021']}
# Keywords: {'keywords': ['Evenementenloket', 'Pop-up café', 'Bezembuurt', 'Goedkeuring']}
# Keywords: {'keywords': ['Vast Bureau', 'werkgroep Wonen en Leven', 'bruin café', 'residentie Den Eendengaerd']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'bezwaar', 'Haachtsesteenweg 158 bus 2', 'leegstandsregister', 'eigenaars', 'ongegrond bezwaar', 'aangetekend schrijven']}
# Keywords: {'keywords': ['vast bureau', 'verslag', 'GROS-raad', '7 februari 2023']}
# Keywords: {'keywords': ['advocaat', 'beroepsprocedure', 'OCMW', 'Nederlandstalige Arbeidsrechtbank', 'Brussel']}
# Keywords: {'keywords': ['rioleringswerken', 'Leeuwbeekstraat', 'princiepsbeslissing', 'buurtweg nr 22', 'openbaar domein']}
# Keywords: {'keywords': ['groenblauwe dooradering', 'bebouwde ruimte', 'oproep 2022', 'kandidatuur', 'goedkeuring']}
# Keywords: {'keywords': ['gemeenteraad', 'zorg- en seniorenloket', 'dienstencentrum De Cirkel', '1 november 2021']}
# Keywords: {'keywords': ['Adviesraden', 'inspraak', 'Merksemse Adviesraad Senioren', 'Collegiale brieven', 'Goedkeuring']}
# Keywords: {'keywords': ['Ondersteuning', 'Onderwijs', 'Samen Duaal Leren Antwerpen', 'SamDuLeA', 'Nominatieve toekenning krediet 2021', 'Goedkeuring']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'schadebestek', 'betonnen verkeersgeleider', 'rondpunt Kasteellaan', 'Drongensesteenweg', 'Neerstraat', '9921 Lievegem', '€ 267,45']}
# Keywords: {'keywords': ['ontwikkeling VK Dronckaertstraat', 'Rekkem', 'dienst', 'aannemer', 'bijkomende rioleringswerken']}
# Keywords: {'keywords': ['omgevingsvergunning', 'Versele Laga nv', 'college van burgemeester en schepenen', 'geldig advies']}
# Keywords: {'keywords': ['college', 'goedkeuringslijst', 'facturen', 'dienstjaar 2022', 'totaal bedrag', '€ 174.270,22']}
# Keywords: {'keywords': ['omgevingsvergunning', 'carport', 'Deinze', 'Winterlaan 43', 'college van burgemeester en schepenen', 'beslissing', '7 april 2021']}
# Keywords: {'keywords': ['Goedkeuren', 'lastvoorwaarden', 'gunningswijze', 'Aankoop', 'straatveegmachine']}
# Keywords: {'keywords': ['Nacht van de duisternis', 'zaterdag 9 oktober 2021', 'Kennisneming', '2021_CBS_01655']}
# Keywords: {'keywords': ['vast bureau', 'voorzitter', 'OCMW-raad', 'agendapunten', '24 maart 2022']}
# Keywords: {'keywords': ['vergunning', 'werken', 'werfzone', 'drinkwateraansluiting', 'De Watergroep', 'Waarschootdorp 5', 'Lievegem', '9 december 2020', '18 december 2020']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'verminderde prestaties', 'halftijds', '55+', 'verlof 7/24', '1 september 2022', 'einde loopbaan']}
# Keywords: {'keywords': ['omgevingsvergunning', 'Temmerman Christophe', 'Waaienberg 99', '9500 Geraardsbergen', 'renoveren van de gevels']}
# Keywords: {'keywords': ['Verzamellijst', 'vastleggingen', 'juli', 'onder 500 euro', 'exclusief btw', 'Kennisneming', '2021_CBS_01335']}
# Keywords: {'keywords': ['Advies rekening', 'dienstjaar 2020', 'Kerkfabriek Sint-Pancratius', 'Zelk']}
# Keywords: {'keywords': ['woning', 'Wijngaardstraat 48', '9500 Geraardsbergen', 'onbewoonbaar verklaard']}
# Keywords: {'keywords': ['onderwijzer', '24 lestijden', 'tijdelijke aanstelling', '1 september 2021', '30 juni 2022']}
# Keywords: {'keywords': ['Kader organisatiebeheersing', 'Keuring', '2022_RMW_00023']}
# Keywords: {'keywords': ['registratiesoftware', 'Cubitec', 'lokaal loket kinderopvang', 'Lievegem', 'college van burgemeester en schepen']}
# Keywords: {'keywords': ['definitieve oplevering', 'fietspad', 'Deinze Vaart Linkeroever', 'Meulebroeckstraat', 'Weg naar de Vaart', 'LAF-2014-012']}
# Keywords: {'keywords': ['raad van bestuur', 'gebruikersovereenkomst', 'OCMW Grobbendonk', 'welzijnsvereniging De Wijngaard', 'zaal De Druif', 'woonzorgcentrum', 'algemeen directeur']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'bijkomende agendapunten', 'syndicaal overleg- en onderhandelingscomité', 'stad/OCMW Aarschot']}
# Keywords: {'keywords': ['heroriënteringstraject', 'gemeentelijke adviesraden', 'Sport', 'Cultuur', 'Jeugd', 'Internationale Samenwerking', 'Wim Van Roy', 'vzw De Wakkere Burger', 'COVID-pandemie', 'eindanalyse', 'slotnotitie', 'stappenplan', '4e pijlerverenigingen', 'GRIS', 'adviesraad', 'dienst internationale samenwerking']}
# Keywords: {'keywords': ['college', 'Kia Vermant Aartselaar', 'flyers', 'wekelijkse markt', 'promotie', 'opendeurdag', '2 juni 2023']}
# Keywords: {'keywords': ['delegatie van bevoegdheid', 'college', 'ondertekenen', 'notariële aktes', 'goedkeuring']}
# Keywords: {'keywords': ['gemeenteraad', '12 oktober 2021', 'Team Secretariaat', 'notulen', 'goedkeuring', 'IOK', 'Fluvius Antwerpen', 'Fluvius Opdrachthoudende Vereniging', 'Iveka', 'Projectvereniging Neteland', 'Politieraad', 'Team Ruimte & Vergunningen', 'Duurzaam patrimoniumbeheer', 'Vlaams Energie Bedrijf', 'Lokaal Energie- en Klimaatpact', 'Project Bike2School', 'Onteigeningen N13', 'Hofeinde', 'Albertkanaalstraat 3', 'Nijlse baan 27', 'Kempens Landschap', 'woonmaatschappij Neteland-Zuiderkempen', 'Team Financieel Management', 'De Volle Vaart', 'schoolinfrastructuur', 'sporthal']}
# Keywords: {'keywords': ['Detachering', 'personeelslid', 'zorgbedrijf Rivierenland', 'Goedkeuring']}
# Keywords: {'keywords': ['Verslavingszorg', 'Samenwerkingsovereenkomst', 'Verslavingskoepel', "OCMW's", 'Herselt', 'Hulshout', 'Westerlo']}
# Keywords: {'keywords': ['raad', 'varia', 'mededelingen']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'verslag', 'cultuurraad', '15 februari 2022']}
# Keywords: {'keywords': ['college', 'vrijwilliger', 'afsprakennota']}
# Keywords: {'keywords': ['Economisch kernversterkend beleidsplan', 'goedkeuring', '2022_GR_00231', 'Sint-Niklaas']}
# Keywords: {'keywords': ['2022_CBS_01794', '2022-101', 'Bestrijkingen', 'vorderingsstaat nr. 1', 'Goedkeuring']}
# Keywords: {'keywords': ['Regionaal Landschap de Voorkempen vzw', 'district Ekeren', 'Aanpassing', 'Goedkeuring']}
# Keywords: {'keywords': ['capaciteitsbepaling', 'gemeentelijke kleuter- en basisschool Gebaska', 'aanmeldingsperiodes', 'inschrijvingsperiodes', 'voorrangsperiodes', 'schooljaar 2022-2023']}
# Keywords: {'keywords': ['recht van voorkoop', 'huis', 'Veldstraat 4', 'Grobbendonk', 'college van burgemeester en schepenen', 'e-voorkooploket VLM']}
# Keywords: {'keywords': ['Lokale Politie', 'kosteloze rechtsbijstand', '2021_CBS_02225', 'Lokeren']}
# Keywords: {'keywords': ['gemeentebelasting', 'sluikstorten', 'gemeente', 'afvalstoffen', 'openbare wegen', 'private wegen', 'administratiekost', 'reglement']}
# Keywords: {'keywords': ['notulen', 'goedkeuring', 'College van Burgemeester en Schepenen']}
# Keywords: {'keywords': ['omgevingsvergunning', 'college van burgemeester en schepenen', 'aanvraag O/2021/323']}
# Keywords: {'keywords': ['brandveiligheidsattest B', 'Lago Grimbergen Pierebad', 'Ringlaan 23-25-27', '1853 Grimbergen', 'geldigheidsduur', 'stappenplan', 'tekortkomingen', 'brandpreventieverslag', 'burgemeester']}
# Keywords: {'keywords': ['verslag', 'zitting', '8 december 2021', 'goedgekeurd']}
# Keywords: {'keywords': ['CBS', 'snelheidsbeperking', 'gewestwegen', 'gemengd verkeer', 'bebouwde kom', '03 augustus 2023']}
# Keywords: {'keywords': ['Besteding maatregel', 'ZOOM 18/25', 'aankoop laptops', 'jongeren', 'Bekrachtiging']}
# Keywords: {'keywords': ['Dienst Onderwijs', 'Flankerend onderwijsbeleid', 'samenwerkingsovereenkomst', 'flexibele trajecten', 'Multi-trajecten', 'Goedkeuring']}
# Keywords: {'keywords': ['college', 'verslag', 'vorige zitting']}
# Keywords: {'keywords': ['vergunning', 'verbouwen', 'woning', 'regulariseren', 'uitbreiding', 'Essestraat 82', 'dossiernummer OMV_2022151259', 'bijzondere voorwaarden', 'bureauruimte', 'verharding', 'heesters', 'struiken']}
# Keywords: {'keywords': ['grafconcessie', 'gemeentelijke begraafplaats', 'Herne']}
# Keywords: {'keywords': ['samenwerkingsovereenkomst', 'Balie Leuven', 'sociale dienstverlening', 'Herent', 'juridische eerstelijnsbijstand', 'Orde van Advocaten te Leuven', 'Commissie Juridische Bijstand']}
# Keywords: {'keywords': ['Dwangbevel', 'Goedkeuring', '2023_VB_00090', 'Lommel']}
# Keywords: {'keywords': ['De Grote Verbinding', 'Ten Eekhovelei 139', '2100 Deurne', 'Aankoop', 'Goedkeuring']}
# Keywords: {'keywords': ['burgemeester', 'toelating', '21 november 2022', 'signalisatie', 'Sterhoek 6', 'werken', 'overweg', 'Infrabel']}
# Keywords: {'keywords': ['Karel Soetelaan 25', 'Ontwerpakte verkoop', 'goedkeuring', '2022_GR_00050']}
# Keywords: {'keywords': ['Notulen', 'vast bureau', '17 november 2022', 'Goedkeuring']}
# ...
# Keywords: {'keywords': ['Bouwonderneming Jehoul', 'college van burgemeester en schepenen', 'Vinkstraat', 'optie', 'loten', 'goedkeuring']}
# Keywords: {'keywords': ['polyvalent medewerker', 'schoonmaak', 'bibliotheek', 'contractueel dienstverband', 'prestatie', 'onbepaalde duur', '12.07.2021']}
# Keywords: {'keywords': ['omgevingsvergunning', 'bouwen van een woning', 'KOLONIE 86', 'Goedkeuring', '2021/309/OMV']}
# Keywords: {'keywords': ['college', 'agenda', 'commissie Samenleven en Vrije Tijd', '7 maart 2022']}
# Keywords: {'keywords': ['college', '70,000 euro', 'raamovereenkomst', 'drukwerk', 'online bestelportaal', 'Vlaamse Overheid', 'Agentschap Facilitair Bedrijf', 'Afdeling Aankoopcentrale', 'Overheidsopdrachten', 'administratieve documentstromen', 'aanslagbiljetten', 'aanmaningen', 'GAS-boetes', 'ARTOOS NV', 'Kampenhout']}
# Keywords: {'keywords': ['aanvraag', 'slopen', 'bestaande loods', 'bouwen', 'gebouwen c & d', 'lokale bedrijven', 'functionele verhardingen', 'parkeerplaatsen', 'publiciteitsinrichtingen', 'goedgekeurd onder voorwaarden']}
# Keywords: {'keywords': ['CD&V-Eendracht', 'culturele infrastructuur', 'kinderopvang', 'dorpskernen', 'investeringsplan']}
# Keywords: {'keywords': ['bestelbonnen', '2022/1778', '2022/1815', 'Goedkeuring', '2022_CBS_01246']}
# Keywords: {'keywords': ['beëindiging', 'arbeidsovereenkomst', 'goedgekeurd']}
# Keywords: {'keywords': ['huwelijk', 'Imeldaziekenhuis', 'vrijstelling', 'trouwboekje', 'college van burgemeester', 'medeleven']}
# Keywords: {'keywords': ['Centrum voor Leren en Werken Gent', 'Centrumreglement', 'Wijziging', '2021_GRMW_00652']}
# Keywords: {'keywords': ['Sluitingsdagen', '2022', 'CBS', 'Lokeren']}
# Keywords: {'keywords': ['samenwerkingsovereenkomst', 'Mind Spring', 'vluchtelingen', 'vast bureau']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'verslag', 'zitting', 'maandag 12 juni 2023']}
# Keywords: {'keywords': ['verlenging', 'concessie', '20 jaar', 'aanvrager', 'kostprijs', '320 euro']}
# Keywords: {'keywords': ['schepencollege', 'verslag', 'multidisciplinaire vergadering', 'Voodoo Village', 'vergaderplanning', 'korpschef', 'diensthoofd Communicatie', 'CP-Event', 'festival']}
# Keywords: {'keywords': ['verkeersmaatregelen', 'Bloktstraat 24a', 'beurtelings verkeer', 'inhaalverbod', 'signalisatieschema', 'signalisatievergunning', 'gemeente Grobbendonk', 'digitale infoborden', 'website', 'facebook', 'griffies', 'correctionele rechtbank', 'politierechtbank', 'Turnhout', 'Team Ruimte & Vergunningen', 'Team Uitvoering & Onderhoud', 'Wijkpost politie', 'Brandweer zone Kempen', 'Noodplanningsambtenaar', 'Kapitein brandweer', 'Team Informatie & Communicatie', 'Team Secretariaat']}
# Keywords: {'keywords': ['OCMW', 'jaarrekening 2019', 'Goedkeuring', '2020_GR_00065']}
# Keywords: {'keywords': ['Innames', 'Veststraat', 'Goedkeuring', '2022_GR_00117']}
# Keywords: {'keywords': ['Moderniseren', 'liftinstallatie', 'Bibliotheek', 'goedkeuring', 'gunning']}
# Keywords: {'keywords': ['Waterlek', 'Cultureel Centrum Mozaïek', 'Proces verbaal', 'minnelijke schikking', 'Goedkeuring']}
# Keywords: {'keywords': ['college', 'bestek', 'overheidsopdracht', 'Slimme digitale post', 'Vlaamse Documentendienst']}
# Keywords: {'keywords': ['Aanvullende dagorde', 'Vooruit', 'Groen', 'Uitbreiding omgevingsraad', 'ervaringsdeskundigen', 'toegankelijkheid', 'Goedkeuring']}
# Keywords: {'keywords': ['omgevingsvergunning', 'verbouwen', 'vrijstaande woning', 'zwembad', 'Deinze', 'Alfons Van Zandyckestraat 21', 'college van burgemeester en schepenen', '27 oktober 2022']}
# Keywords: {'keywords': ['tijdelijke verordening', 'wegverkeer', 'station Langdorp', '3200 Aarschot', 'snoeiwerken', 'onderhoud parkeerplaatsen']}
# Keywords: {'keywords': ['omgevingsvergunning', 'De Mulder Gertjan', 'Driesstraat 64A', '9506 Geraardsbergen', 'kadastraal gekend', '10/A/0475A', '10/A/0475G', 'wijzigen van lot 1', 'breedte van de losweg', 'kroonlijsthoogte', 'dakvorm', 'garage']}
# Keywords: {'keywords': ['halftijdse loopbaanonderbreking', 'ouderschapsverlof', 'leraar instrument', 'klassiek', 'harp', 'muziekinitiatie', 'Kunstacademie Geraardsbergen', '13 september 2021', '12 mei 2022']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'werken', 'Mertens schilderwerken bvba', 'Wuustwezel']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'verslag', 'vergadering', 'raad van bestuur', 'Imewo', '10 oktober 2021']}
# Keywords: {'keywords': ['Mandaten', 'Goedkeuring', '2022_CBS_01872']}
# Keywords: {'keywords': ['Wegenis-en rioleringswerken', 'Heirbaan', 'Reenstraat', 'Aartrijtstraat', 'Dopheistraat', 'Verrekening 1', 'Goedkeuring']}
# Keywords: {'keywords': ['Ruimen van baangrachten', 'Verlenging 2', '2021_CBS_01342', 'Lokeren']}
# Keywords: {'keywords': ['Maaien', 'wegbermen', '2020', '2023', 'Perceel 1', 'Verlenging', 'Goedkeuring', 'gunning']}
# Keywords: {'keywords': ['Subsidie', 'stookolietanks', 'verwijderen', 'opvullen', 'buiten gebruik stellen', 'Goedkeuring']}
# Keywords: {'keywords': ['Districtsraad', 'Notulen', '1 april 2021', 'Goedkeuring', 'Antwerpen']}
# Keywords: {'keywords': ['gemeenteraad', 'goedkeuring', 'werkingsverslag 2020', 'Sportregio Midden-Provincie ILV', 'gemeenteraadsbeslissing', 'secretariaat']}
# Keywords: {'keywords': ['Boombox', 'Boombox 5 Years', 'event', '20 augustus 2022', 'feestterrein', 'Hezerstraat 56', '3640 Molenbeersel', 'voorwaarden']}
# Keywords: {'keywords': ['deontologische code', 'gemeenteraad', 'deontologische commissie', 'artikel 39', 'decreet lokaal bestuur', 'VVSG', 'openbare besturen', 'raad voor maatschappelijk welzijn', 'college van burgemeester en schepenen']}
# Keywords: {'keywords': ['Schepencollege', 'voorgestelde meerwerken', 'dossier', 'verbeteringswerken diverse wegen 2021', 'offerte']}
# Keywords: {'keywords': ['Vernieuwen', 'lichtstraat', 'plat dak', "'t Schippershof", 'Goedkeuring', 'gunning']}
# Keywords: {'keywords': ['diverse zaaiwerken', 'perceel 2', 'inzaaien bloemenweiden', 'begraafplaats Moorselestraat', 'definitief opgeleverd']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'gunning', 'dakverdichting', 'OC Hondius']}
# Keywords: {'keywords': ['meldingen', '19 juni', '25 juni 2023', 'kennisname']}
# Keywords: {'keywords': ['Week van de vrijwilliger', '2024', 'Locatie', 'programma']}
# Keywords: {'keywords': ['college', 'betrekking', 'helpdeskmedewerker ICT', 'niveau C1 - C3', 'wervingsreserve', 'geldigheidsduur', '6 maanden']}
# Keywords: {'keywords': ['Lokaal Energie- en Klimaatpact', 'Goedkeuring', '2022_CBS_01156']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'fietslease', 'personeel', 'Besluit van de Vlaamse Regering', '12 maart 2021']}
# Keywords: {'keywords': ['onderzoek', 'scheidingsmuren', 'afbraak', 'achterbouw', 'Aarsele-Dorp 22', '8700 Tielt', 'aanschrijven', 'aanpalenden']}
# Keywords: {'keywords': ['Welzijnszorg Kempen', 'OCMW', 'jaarrekening 2022', 'arrondissement Turnhout', 'algemene vergadering', '31 mei 2023', 'dienstverlening', 'welzijn', 'gezondheid', 'kwetsbare mens', 'raad', 'advies']}
# Keywords: {'keywords': ['Doortocht Dustride', 'WTC Groez Rock', 'zaterdag 10 juni 2023', 'Goedkeuring']}
# Keywords: {'keywords': ['Palladium', 'kansspelinrichting', 'Rijselstraat 225', 'Menen', 'addendum', 'convenant 2014', 'NV Palladium', 'NV Circus', 'college van burgemeester en schepenen', 'vergunning B', 'Kansspelcommissie']}
# Keywords: {'keywords': ['OCMW-raad', 'goedkeuring', 'notulen', 'vergadering', '20 maart 2023']}
# Keywords: {'keywords': ['Vertegenwoordiging', 'STUK Kunstencentrum vzw', 'Vervanging', 'Algemene vergadering', 'voordracht kandidaat-bestuurder', 'Goedkeuring']}
# Keywords: {'keywords': ['KAJ Anzegem', 'publiciteit', 'openbare weg', 'Bib Anzegem', 'De Wortel', 'kerk', 'carwash', 'parking Delhaize', 'Anzegem', 'zaterdag 23 april 2022', 'zaterdag 7 mei 2022', 'gemeentewegen', 'toelating']}
# Keywords: {'keywords': ["'t Gerief", "'t Plankse", 'Ten Diensten', 'ANPE', 'voordracht leden', 'algemene vergadering', 'kandidaat-bestuurder', 'bestuursorgaan', 'goedkeuring']}
# Keywords: {'keywords': ['Vragen', 'antwoorden']}
# Keywords: {'keywords': ['schepencollege', 'aankoop', 'elektrische wagen', 'E-Lichte bestelwagen', 'korte wielbasis', 'kleine accu', 'tarieven', 'gegunde offerte', 'Stellantis']}
# Keywords: {'keywords': ['verzoek tot opname', 'vergunningenregister', 'Koeistraat 28A', 'Arendonk', 'weigering opname', 'goedkeuring']}
# Keywords: {'keywords': ['tijdelijk verkeersreglement', 'bloemenverkoop', 'Allerheiligen', '23 oktober', '2 november 2021']}
# Keywords: {'keywords': ['bestelling', 'broodjes', 'receptie', 'Gemeentehuis']}
# Keywords: {'keywords': ['Aanvraag omgevingsproject', 'OMV/2021/0081', 'Vissersstraat', 'paardenstal', 'Goedkeuring']}
# Keywords: {'keywords': ['raad', 'verwerpt', 'aanvullend agendapunt']}
# Keywords: {'keywords': ['Vast Bureau', 'woning', 'sociaal verhuren']}
# Keywords: {'keywords': ['vrijwilligers', 'evenementen', 'feestelijkheden', '2023', 'lijst', 'goedkeuren']}
# Keywords: {'keywords': ['Aanvraag', 'bewindvoering', 'Goedkeuring', '2021_VB_00593']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'Vredeplaats', 'stilstaan- en parkeerverbod', 'zondag 10 september 2023', 'Arthur Dezangrélaan', 'nadar hekken', 'bord C3', 'verbodsborden E1', 'verbodsborden C3', 'verbodsborden F41', 'evenement', 'inwoners']}
# Keywords: {'keywords': ['college', 'vorderingsstaat 3', 'bouwen', 'skatepark']}
# Keywords: {'keywords': ['samenwerkingsprotocol', 'wonen-welzijn', 'afsprakennota']}
# Keywords: {'keywords': ['Collegebeslissing', 'wekelijkse planning', 'cel Middelenbeheer', 'cel Wegen en Domeinen']}
# Keywords: {'keywords': ['tijdelijke', 'drankvergunning', 'aanvraag']}
# Keywords: {'keywords': ['stedenbouwkundig attest', 'vrijstaande woning', 'vellen van bomen', 'De Renlaan 37', 'Brecht', 'kadasternummer', 'afd. 5', 'sectie A 139 X']}
# Keywords: {'keywords': ['omgevingsvergunning', 'college van burgemeester en schepenen', 'Brakelstraat 4']}
# Keywords: {'keywords': ['investeringssubsidie', '2021', 'kerkfabriek Heilige Margaretha', 'Sint-Margriete', 'college van burgemeester en schepenen']}
# Keywords: {'keywords': ['Doorsteek Kerkstraat-Mudhoven', 'goedkeuring vorderingsstaat 5', '2019-102', '2022_CBS_02029', 'Goedkeuring']}
# Keywords: {'keywords': ['verlichting', 'loopparcours', 'Prinsenbos', 'led-verlichting']}
# Keywords: {'keywords': ['verlenging', 'concessie', '30 jaar', 'aanvrager', 'kostprijs', '480 euro']}
# Keywords: {'keywords': ['student verzorging', 'contractueel verband', 'voltijdse prestaties', 'woonzorgcentrum De Populier', '475 uur', '1 januari 2023', '31 december 2023']}
# Keywords: {'keywords': ['Prijssubsidiereglement', '2023', 'Vaststelling']}
# Keywords: {'keywords': ['plenaire vergadering', '28 juni 2023', 'Provinciaal Ruimtelijk Uitvoeringsplan', 'RUP Kauwenhoek', 'site Europoint', 'Waregem']}
# Keywords: {'keywords': ['Weigering', 'erkenning', 'arbeidsongeval', 'P&V Verzekeringen']}
# Keywords: {'keywords': ['college', 'akkoord', 'aangepaste lijst', 'muziekcheques']}
# Keywords: {'keywords': ['parkeerverbod', 'Kerkstraat 2-4', 'Waarschootdorp 5', 'Lievegem', '20 maart 2023', '31 maart 2023', '7.00 uur', '18.00 uur']}
# Keywords: {'keywords': ['Gemeenteraad', 'aankoop', '93 m² grond', 'Poekevoetweg nr. 22', 'Ruiselede', 'kadastraal gekend', '1e afdeling', 'Sectie C', '168/C', '168/D', '170/A', '170/B']}
# Keywords: {'keywords': ['burgemeester', 'toelating', 'Markt 1', '9930 Lievegem', 'parkeerplaatsen', 'linkerparkeerstrook', 'huwelijk', '11 juni 2022', '11.00 uur', '12.30 uur']}
# Keywords: {'keywords': ['omgevingsvergunning', 'hernieuwing', 'verandering', 'bedrijf', 'paddenstoelenmycelium', 'verpakkingsmateriaal', 'Veldeken 27-29']}
# Keywords: {'keywords': ['Evenementenloket', 'Aanvragen huwelijken', 'openlucht', 'Extra aanvraag', 'zomer 2021', 'Goedkeuring']}
# Keywords: {'keywords': ['Goedgekeurd', 'vacantverklaring']}
# Keywords: {'keywords': ['burgemeester', 'toelating', 'Lindenstraat 13', '8730 Beernem', 'openbaar domein', 'signalisatie', 'werken', 'nutsleidingen', '17 mei 2023', '27 mei 2023']}
# Keywords: {'keywords': ['Lokaal Energie- en Klimaatpact', 'Ondertekenen', 'Goedkeuring', '2021_GR_00042']}
# Keywords: {'keywords': ['Goedkeuring', 'vorderingsstaat 9', 'APK Construct NV', 'Steenovenstraat 2A', '2390 Malle', 'Ruwbouw project', 'site Klaverstraat', 'Koolskamp', '256.990,17 € excl. btw', '310.958,11 € incl. 21% btw', '53.967,94 € btw medecontractant', '700.948,64 € excl. btw', '848.147,86 € incl. 21% btw']}
# Keywords: {'keywords': ['Secretariaat', 'gemeente', 'Notulen', 'verslag', 'vergadering', 'Goedkeuring', 'Goedgekeurd']}
# Keywords: {'keywords': ['Toekenning', 'nominatieve subsidies', '2023', 'Goedkeuring']}
# Keywords: {'keywords': ['raad', 'agenda', 'gewone algemene jaarvergadering', 'Ethias', '9 juni 2022']}
# Keywords: {'keywords': ['samenwerkingsovereenkomst', 'Agentschap Zorg en Gezondheid', 'complementaire engagementen', 'Vlaamse Regering', 'subsidie', 'lokale besturen', 'contact- en bronopsporing', 'COVID-19 pandemie', 'bestrijding', 'Bekrachtiging']}
# Keywords: {'keywords': ['Raming', 'euro', 'excl. btw', 'incl. btw', 'Openbare procedure']}
# Keywords: {'keywords': ['Evenementendienst', 'Vlaanderen Muziekland', 'Goedkeuring']}
# Keywords: {'keywords': ['Beslissing', 'deputatie', 'provincie Oost-Vlaanderen', 'dossier', 'OMV_2019155913']}
# Keywords: {'keywords': ['Feesten op terras', '20 tot en met 23 juli 2023', 'Café Hof ten Blote', 'burgemeester', 'evenement']}
# Keywords: {'keywords': ['toelage', 'sportverenigingen', 'onderhoud', 'buitenterreinen']}
# Keywords: {'keywords': ['vergunning', 'werken', 'leidingen', 'Fluvius', 'Molenbergstraat', 'Boven', 'Ter Wal', 'Lievegem', '8 november 2021', '24 november 2021']}
# Keywords: {'keywords': ['stedelijke renovatiepremie', 'Bareelstraat 74', 'Lokeren', 'RENO/2022/14', 'AW2022/7440', 'Toekenning']}
# Keywords: {'keywords': ['subsidies', 'doelgroepwerknemers', 'pesticidenvrij onderhoud', 'kerkhoven', 'maai- en knotwerken', 'Zwalmbeek', 'college van burgemeester en schepenen']}
# Keywords: {'keywords': ['Afkoppeling', 'binnengebied', 'Eksaarde', 'PV van einde der werken', 'Goedkeuring']}
# Keywords: {'keywords': ['Octopusgemeente', 'schooljaar 2023-2024', 'college van burgemeester en schepenen', 'goedkeuring', 'registreren']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'melding', 'exploitatie', 'ingedeelde inrichting', 'activiteit klasse 3', 'tijdelijke bronbemaling', 'bouwkundige werken']}
# Keywords: {'keywords': ['college', 'landmeter', 'Artois bv', 'nieuw plan', 'afpaling']}
# Keywords: {'keywords': ['schepencollege', 'onregelmatige prestaties', 'overuren', 'toeslagen', 'nacht', 'zaterdag', 'zondag', 'feestdagen', 'permanentietoelagen', 'fietsvergoedingen', 'budgethouderschap']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'factuur', 'bestelbon', 'betaalbaar']}
# Keywords: {'keywords': ['schepencollege', 'brief', '1 oktober 2021']}
# Keywords: {'keywords': ['college van burgemeester en schepenen', 'borgsom', 'stedenbouwkundige vergunning', 'omgevingsvergunning']}
# Keywords: {'keywords': ['Notulen', 'Raad voor Maatschappelijk Welzijn', '27 februari 2023', 'Goedkeuring', 'Lokeren']}
# Keywords: {'keywords': ['tijdelijke jurist', 'A1a-A2a', 'Administratieve beleidsondersteuning', 'voltijds contractueel verband', 'vervangingscontract', 'college van burgemeester en schepenen']}
# Keywords: {'keywords': ['toezichter', 'redder', 'niveau C', 'voltijdse prestaties', 'contractueel verband', 'onbepaalde duur']}
# Keywords: {'keywords': ['wielerwedstrijd', 'Edewalle', '20 augustus 2022']}
# Keywords: {'keywords': ['onderwijzeres', 'gemeenteschool', 'verlofstelsel', 'schooljaar 2022-2023']}
# Keywords: {'keywords': ['Parking Rupel', 'detectiesysteem', 'IP-Mobile NV', 'Nieuwlandlaan 111', '3200 Aarschot', 'Kaai/Windstraat', '3.099,44 €', 'BTW excl.']}
# Keywords: {'keywords': ['subsidie', 'buurtfeest', 'straatfeest', 'Kouterstraat', 'college van burgemeester en schepenen']}

# %% [markdown]
# # Summarization tasks

# %%
import requests

#for simplicity, we will use the search endpoint of the LokaalBeslist API to get the agenda items

def get_agenda_items(search_content, location_id=None, max_results=2):
    # Define the URL and query parameters

    params = {
        "page[size]": max_results,
        "page[number]": 0,
        "filter[:fuzzy:search_content]": search_content,
        "sort[session_planned_start.field]": "desc"
    }

    if location_id is not None:
        params["filter[:has:search_location_id]"] = "t"
        params["filter[:terms:search_location_id]"] = location_id

    # Define the headers
    headers = {
        "Accept": "*/*",
        "Accept-Encoding": "gzip, deflate, br, zstd",
        "Accept-Language": "en-US,en;q=0.9,nl;q=0.8,fr;q=0.7,it;q=0.6,es;q=0.5",
        "Cache-Control": "no-cache",
        "Referer": "https://lokaalbeslist.vlaanderen.be/agendapunten?gemeentes=Gent&trefwoord=blaarmeersen",
        "Sec-Ch-Ua": '"Google Chrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
        "Sec-Ch-Ua-Mobile": "?0",
        "Sec-Ch-Ua-Platform": '"Windows"',
        "Sec-Fetch-Dest": "empty",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "same-origin",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"
    }

    # Optionally, include cookies if needed
    cookies = {
        "shortscc": "2",
        "proxy_session": "QTEyOEdDTQ.el1yihjiovv1IzOv4xxDo-2k783xBilgm6DzC8M2hNHVONzg6cz0Q_toOg4.XIPR-bEY0du7d-P0.phHm39QaT8g7-y7fxaQ9XYA5M0D37dxxvxmJSbRGWk3nVHXjGbWanMk8nrl6rXQiKfW7M8VvPhezCzWQgSxXCcrRvQMkJyYqt6ggnhD-A6Bmji1NnUhYmbDO9oIvtSnBIkg5d3DLwlvMGJOjJDGu66wkVLezSXSVGQbShnMv9yMv8FN0IDHruobpWWYr1JQcj71pAYL-WCCFS2KjuBDL.vIGRc-k1TAO5I922gCr_vwDnt"
    }

    # Make the GET request
    response = requests.get(LOKAALBESLIST_SEARCH_ENDPOINT, headers=headers, params=params, cookies=cookies)

    # Check the response status
    if response.status_code == 200:
        # Return the response content
        return response.json()
    else:
        raise Exception(f"Request failed with status code: {response.status_code}")

def process_results(results):
    processed_results = []
    for result in results:
        if result['type'] == 'agenda-item':
            title = result['attributes']['title']
            description = result['attributes']['description']

            # Use the resolution title and description if the title and description are None
            if title is None:
                title = result['attributes']['resolution_title']
            if description is None:
                description = result['attributes']['resolution_description']

            processed_result = {
                'title': title,
                'description': description,
                'uuid': result['id'],
                'uri': result['attributes']['uri']
            }
            processed_results.append(processed_result)
    return processed_results

def get_context_for_llm(search_term, location_id = None, max_results=2):
    # Get the agenda items related to the search term
    agenda_items = get_agenda_items(search_term, location_id, max_results)
    num_results = agenda_items['count']
    formatted_results = process_results(agenda_items['data'])
    
    # Format the results into a string
    context = f"Found {min(num_results, len(formatted_results))} agenda items:\n"
    for i, result in enumerate(formatted_results, start=1):
        context += f"{i}. {result['title']} ({result['uri']})\n"
        if result['description']:
            context += f"\t+ Description: {result['description']}\n"

    # Return the context
    return context, formatted_results

# %%
def overview_agendapunten_task(search_term, context, include_system_message=True):
    task=f"""Task: Provide an overview of all the relevant items related to '{search_term}' mentioned in the context.
For each item, provide a detailed summary of what the item is about and the link at the end. Group related items by topic and use topic headers. Clarity: Ensure the summaries are clear and straightforward, avoiding unnecessary jargon, verbose descriptions and unnecessary details.

      
Format:
- **Topic Header**: Start with a topic header to group related items.
    - **Title**:
        - **Samenvatting**: A clear and concise summary of the item, including the main points without complex jargon, simple in grammar and structure.
        - **Link**: Provide the link in brackets at the end.

Example:
Overzicht van de agendapunten met betrekking tot 'Scaldisstraat':
- **Verkeersregelment**:
    - *Wijziging van het aanvullend reglement - Scaldisstraat (inclusief regularisatie en nieuwe parkeerplaats voor autodelen):**
        - **Samenvatting**: Dit voorstel gaat over het aanpassen van de verkeersregels voor de Scaldisstraat, inclusief het reguleren van bestaande situaties die niet volgens de regels zijn en het creëren van een nieuwe parkeerplaats speciaal voor autodelen.
        - **Link**: https://data.gent.be/id/agendapunten/22.0111.1538.0398
    ...
- **Nuts- en infrastructuurwerken**:
    - *Toelating voor het uitvoeren van nuts- en infrastructuurwerken - Scaldisstraat 50:**
        - **Samenvatting**: De aanvraag is om Farys - Klantenwerken - Gent toestemming te geven voor het uitvoeren van nuts- en infrastructuurwerken op Scaldisstraat 50, voornamelijk voor het plaatsen van een drinkwateraftakking.
        - **Link**: https://data.gent.be/id/agendapunten/23.1017.3020.9047
...
"""

    return generate_rag_prompt(task, context, include_system_message)

search_term = "landbouwloodsen"
max_results = 40

context, results = get_context_for_llm(search_term,None, max_results)
prompt_string, system_message = overview_agendapunten_task(search_term, context, False)
print(f"{prompt_string}")
# Out:
# ####
# Context: Found 40 agenda items:
# 1. RMT-VGN-2023-0949-AGPP-DEP-01 (http://data.lblod.info/id/agendapunten/6645E08D076AEA6F2CBED875)
# 	+ Description: Boutersem-Aanvraag voor stedenbouwkundige handelingen en voor ingedeelde inrichtingen en activiteiten ingediend door Dehertogh voor de bouw van een nieuwe landbouwloods en het aanleggen van infiltratievoorziening en het veranderen van de varkenshouderij, Broekstraat 24
# 2. RMT-VGN-2023-1062-BGP-DEP-01 (http://data.lblod.info/id/agendapunten/6645DCE8076AEA6F2CBED7CF)
# 	+ Description: Kampenhout-beroep tegen de vergunning onder voorwaarden van 04 december 2023, verleend voor een functiewijziging van landbouwloods naar opslag van materialen, Sint-Servaesstraat
# 3. RUP Kern Verona Voorlopige vaststelling  (https://bertem.meetingburger.net/gr/8a489877-7fdb-4b29-99d9-c3480b881a88/bertem.meetingburger.net/gr/8a489877-7fdb-4b29-99d9-c3480b881a88#300d49ab-baec-49c4-b013-6654c2da9b02)
# 	+ Description: RUP Kern Verona Voorlopige vaststelling
# 4. 2024_CBS_00469 - Omgevingsvergunning - verbouwen van landbouwloods tot 8 gastenlogies - Keerzelaarstraat 1A - Vergunning (https://data.langemark-poelkapelle.be/id/agendapunten/24.0403.8906.8709)
# 5. 2024_CBS_00637 - 2023/00207/OV - gedeeltelijk voorwaardelijk gunstig advies en gedeeltelijk ongunstig advies inzake beroep omgevingsvergunning voor het slopen van een bestaande woning en bouwen van een landbouwloods met bijhorende bedrijfswoning, Mekingenweg 115, 1600 Sint-Pieters-Leeuw - Beslissing (https://data.sint-pieters-leeuw.be/id/agendapunten/24.0314.8150.3716)
# 6. 29.  Verlenen van een advies voor een omgevingsvergunning in tweede aanleg (beroepsprocedure) voor een functiewijziging van landbouwloods (aardappelloods) naar opslag op een terrein met adres Gielestraat ZN (OMV_2023109194) (https://lblod.maarkedal.be/LBLODWeb/id/agendapunt/ed6ac8e4f22b4e54b8684083175cb5cb-24288)
# 	+ Description:
#                                 Er wordt beslist om geen bijkomend advies uit te brengen tijdens de beroepsperiode. Het bestuur blijft bij de eerder genomen beslissing, namelijk om de functiewijziging naar opslag te vergunnen.
#
# 7. 100. BEROEP_LAATSTE_AANLEG - OMV_2023025015 - Omgevingsvergunning verlenen voor het aspect wijzigen van de functies zone-eigen woning en woningbijgebouw naar residentiële (zonevreemde) woning en woningbijgebouw, van ambachtelijke smederij naar seminarieruimte, van landbouwopslag naar opslag (loods 1, 2 en3), slopen van een landbouwloods, berging en regularisatie van de sloop van een berging, gelegen te Oostkamp  (https://lblod.west-vlaanderen.be/LBLODWeb/id/agendapunt/ca48ac7482dd479babfd490a97db9d8d-156239)
# 	+ Description:
#
#
# 8. 22.  Kennisname verklaring ontvankelijkheid en volledigheid van een beroep tegen een collegebeslissing met dossiernummer OMV_2023109194 (https://lblod.maarkedal.be/LBLODWeb/id/agendapunt/ef6c056978714cffb2d563f858a5a262-24174)
# 	+ Description:
#                                 Er wordt kennis genomen van de ontvankelijkheid en volledigheid van een beroep tegen een collegebeslissing met dossiernummer OMV_2023109194. Betreft een functiewijziging van landbouwloods naar opslag, Gielestraat zn te 9688 Maarkedal.
#
# 9. 17.  Verlenen omgevingsvergunning tot uitbreiding landbouwloods voor aardappelopslag op een terrein met adres Hasselstraat 22, 9968 Assenede en met als kadastrale omschrijving ASSENEDE 3 AFD (BASSEVELDE) C 0513 D ASSENEDE 3 AFD (BASSEVELDE) C 0512 A . (https://lblod.assenede.be/LBLODWeb/id/agendapunt/48a5a0c83c7b4eb09d8ef1a7dd49c9b0-53313)
# 	+ Description:
#                                 Verlenen omgevingsvergunning tot uitbreiding landbouwloods voor aardappelopslag op een terrein met adres Hasselstraat 22, 9968 Assenede en met als kadastrale omschrijving ASSENEDE 3 AFD (BASSEVELDE) C 0513 D ASSENEDE 3 AFD (BASSEVELDE) C 0512 A.
#
# 10. 2024_CBS_00467 - OMV/2024/10 - advies van het college van burgemeester en schepenen over een omgevingsaanvraag voor het regulariseren van de landbouwloods, de melkveestal en het uitbreiden van een landbouwloods bij een vergund melkveebedrijf (https://data.maasmechelen.be/id/agendapunten/24.0216.5022.4365)
# 	+ Description:  Type handelingen: stedenbouwkundige handelingen als vermeld in artikel 4.2.2 en artikel 4.2.4 van de VCROde exploitatie van een ingedeelde inrichting of activiteit van de derde klasse als vermeld in artikel 5.2.1 van het DABMOmschrijving: het regulariseren van de landbouwloods, de melkveestal en het uitbreiden van een landbouwloods bij een vergund melkveebedrijf
# 11. 1. Advies omgevingsvergunning in beroepsprocedure bij Departement Omgeving tegen beslissing deputatie houdende weigering omgevingsvergunning voor het bouwen van een landbouwloods en vergroten van vijver op de site gelegen Zandvoordeplaats 77 (https://lblod.zonnebeke.be/LBLODWeb/id/agendapunt/7da1ca4cbb76446180d6b9b77c838a10-65235)
# 	+ Description:
# Het college verleent een ongunstig advies.
#
# 12. Planologisch attest Targa Tuinen  (https://bertem.meetingburger.net/gr/303ba86d-7caa-4a34-a0eb-5231d84df5e7/bertem.meetingburger.net/gr/303ba86d-7caa-4a34-a0eb-5231d84df5e7#06e734e7-909d-400f-a335-4c0bc983df36)
# 	+ Description: Planologisch attest Targa Tuinen
# 13. 94. Omgevingsvergunning voor bouwen tweede bedrijfswoning met landbouwloods, regularisatie mestvaalt, aanleg verhardingen en aanpassingen vlarem rubrieken (O/2023/377) (https://lblod.temse.be/LBLODWeb/id/agendapunt/c916147561964a41aae68a9e5cb91885-65199)
# 	+ Description:
#
#
# 14. Omgevingsvergunning OMV2023277 voor het slopen van een varkensstal, het bouwen van een landbouwloods, het aanleggen van een verharding en een infiltratiezone en de exploitatie van een akkerbouwbedrijf op een perceel gelegen Kleinrees 30, 2460 Kasterlee, (afd. 1) sectie H 538 B en (afd. 1) sectie H 538 C / Voorwaardelijk vergund  (https://kasterlee.meetingburger.net/cbs/53f9d028-7b76-45c2-83b9-7828642c48d2/kasterlee.meetingburger.net/cbs/53f9d028-7b76-45c2-83b9-7828642c48d2#ec5794b2-3643-4c0d-b5b4-f34a787876f6)
# 	+ Description: Omgevingsvergunning OMV2023277 voor het slopen van een varkensstal, het bouwen van een landbouwloods, het aanleggen van een verharding en een infiltratiezone en de exploitatie van een akkerbouwbedrijf op een perceel gelegen Kleinrees 30, 2460 Kasterlee, (afd. 1) sectie H 538 B en (afd. 1) sectie H 538 C / Voorwaardelijk vergund
# 15. 1.  Gunstig advies aan de deputatie voor het bouwen van een landbouwloods, gelegen te Poelstraat ZN, 9060 Zelzate (intern nummer: O/2023/971) (https://lblod.zelzate.be/LBLODWeb/id/agendapunt/0413a2c9c2bd4c3aa3ae255389f691f3-7389)
# 	+ Description:
#
#
# 16. 18.  O_2022_269: Serge Stroo, Oude Sabtsweg 2, 8340 Damme vraagt aan: bouwen landbouwloods met aanhorigheden en verbouwen bestaande loods en exploiteren van een nieuwe inrichting, Oude-Heernisstraat z.n., kadastraal gekend afd. 4, sectie C, nr. 0180 P. (https://lblod.damme.be/LBLODWeb/id/agendapunt/6e48e93c04284e54a22164e17d831e55-22187)
# 	+ Description:
#
#
# 17. 5.  OMG - Omgevingsvergunning - uitbreiden landbouwloodsen - Heerweg 47 (https://lblod.horebeke.be/LBLODWeb/id/agendapunt/ea9d102d049f4b4b8435c16025d9d0ab-1287)
# 	+ Description:
#
#
# 18. ['2023_CBS_03148 - \nOMV/2023/375 - voorwaardelijke vergunning voor het verbouwen met functiewijziging van een schuur naar een landbouwloods', '2023_CBS_03148 - ,OMV/2023/375 - voorwaardelijke vergunning voor het verbouwen met functiewijziging van een schuur naar een landbouwloods'] (https://data.maasmechelen.be/id/agendapunten/23.1219.7465.6129)
# 	+ Description:  Voorwaardelijke omgevingsvergunningType handelingen: stedenbouwkundige handelingen als vermeld in artikel 4.2.2 en artikel 4.2.4 van de VCROOmschrijving: het verbouwen met functiewijziging van een schuur naar een landbouwloods
# 19. 29.  Verlenen van een omgevingsvergunning voor een functiewijziging van een landbouwloods (aardappelloods) naar opslag op een terrein met adres Gielestraat ZN (OMV_2023109194) (https://lblod.maarkedal.be/LBLODWeb/id/agendapunt/5d6c7ac2cfea4431ad26e6dddfc27ac3-23584)
# 	+ Description:
#                                 Er wordt een omgevingsvergunning verleend voor een functiewijziging van een landbouwloods (aardappelloods) naar opslag op een terrein met adres Gielestraat ZN en met als kadastrale omschrijving Maarkedal 4 Afd (Schorisse), Sectie B, Perceel 0076D2.
#
# 20. Omgevingsvergunning - besluit van de deputatie van de provincie Antwerpen van 30 november 2023 over een aanvraag in de Oostmalsesteenweg 363 te 2310 Rijkevorsel betreffende het bouwen van een landbouwloods, het aanleggen van bijkomende erfverharding, het aanleggen van een overwelving, het aanplanten van een groenscherm, het veranderen van een milieu-ingedeelde inrichting of activiteit van klasse 2 met betrekking tot een landbouwbedrijf - kennisneming - niet aantekenen van beroep - goedkeuring  (https://malle.meetingburger.net/cbs/e71c66c8-7ec0-4bd9-a8a3-78027c7f7160/malle.meetingburger.net/cbs/e71c66c8-7ec0-4bd9-a8a3-78027c7f7160#361e6767-7c0c-482d-9c23-17c14ad3e751)
# 	+ Description: Omgevingsvergunning - besluit van de deputatie van de provincie Antwerpen van 30 november 2023 over een aanvraag in de Oostmalsesteenweg 363 te 2310 Rijkevorsel betreffende het bouwen van een landbouwloods, het aanleggen van bijkomende erfverharding, het aanleggen van een overwelving, het aanplanten van een groenscherm, het veranderen van een milieu-ingedeelde inrichting of activiteit van klasse 2 met betrekking tot een landbouwbedrijf - kennisneming - niet aantekenen van beroep - goedkeuring
# 21. 47.  Brief aan het college van burgemeester en schepenen omtrent aanmaning metaalbewerkingsbedrijf in landbouwloods, - akteneming (https://lblod.veurne.be/LBLODWeb/id/agendapunt/2f4dbf6801da4407af2781309094c5ae-39320)
# 	+ Description: [',                                ,                            ', '\n                                \n                            ']
# 22. 2023_CBS_02726 - 2023/00207/OV - gedeeltelijk vergund onder voorwaarden en gedeeltelijke weigering van een omgevingsvergunning voor het slopen van een bestaande woning en bouwen van een landbouwloods met bijhorende bedrijfswoning - Mekingenweg 115, 1600 Sint-Pieters-Leeuw - Beslissing (https://data.sint-pieters-leeuw.be/id/agendapunten/23.1130.5088.3450)
# 23. 2023_CBS_01909 - Kennisneming en opname in het vergunningenregister van de uitspraak van de Deputatie betreffende het bouwen van een landbouwloods met mestsilo en aanleggen van verhardingen en infiltratiebekken + veranderen van een bestaande klasse 1-inrichting (gemengd veebedrijf) gelegen Mgr. Broekxstraat 5 en 6 te 3990 Peer. (AVI2023/0157). - Keuring (https://data.peer.be/id/agendapunten/23.1127.0379.7393)
# 	+ Description: Op 19 mei 2023, vervolledigd op 23 juni 2023 dient Jelle Broekx bij de deputatie van de provincie Limburg een aanvraag in voor het bouwen van een landbouwloods met mestsilo en aanleggen van verhardingen en infiltratiebekken + veranderen van een bestaande klasse 1-inrichting (gemengd veebedrijf) gelegen Mgr. Broekxstraat 5 en 6 te 3990 Peer. (AVI2023/0157). N.a.v. het ongunstig advies van AGOP werd de bouw van de mestsilo uit de aanvraag gehaald. In zitting van 16 november 2023 verleent de Deputatie onder voorwaarden bepaald in het besluit de omgevingsvergunning. Tegen deze beslissing kan nog beroep worden ingediend bij de Vlaamse Regering.
# 24. 3. OMV_2023079114 - Aanvraag tot omgevingsvergunning 2023/4922 tot de functiewijziging: landbouwloodsen worden opslagruimtes voor materieel en materiaal (geen landbouw), gelegen in Lendelede, Kortrijksestraat 51, sectie D 345 G, 357 C. (https://lblod.lendelede.be/LBLODWeb/id/agendapunt/96729d626c654e708bc519b0b99b51e7-7744)
# 	+ Description: ['\n                                a) Kennisname einde openbaar onderzoek.\nb) Kennisname advies van Dpt Landbouw en Visserij.\nc) Vergunning wordt verleend onder voorwaarden.\n                            ', ',                                a) Kennisname einde openbaar onderzoek.,b) Kennisname advies van Dpt Landbouw en Visserij.,c) Vergunning wordt verleend onder voorwaarden.,                            ']
# 25. 109. BEROEP_LAATSTE_AANLEG - OMV_2023009269 - Omgevingsvergunning verlenen voor het aspect herbouwen van zonevreemde woning na afbraak bestaande woning en wijzigen functie van landbouwloods, gelegen te Middelkerke  (https://lblod.west-vlaanderen.be/LBLODWeb/id/agendapunt/41ea8cb8a7954307b9939a9b7dba3c40-152690)
# 	+ Description: [',                                ,                            ', '\n                                \n                            ']
# 26. 8. 2023/179 Stopzetten van een varkenshouderij + het slopen en herbouwen van een bedrijfswoning en landbouwloods, het verbouwen en de functiewijziging van woning naar landbouwberging - Aanvragers dhr. en mevr. Vanneste-Vandepitte - Afleveren vergunning. (https://lblod.diksmuide.be/LBLODWeb/id/agendapunt/f3e4fd3500ee4d7c9b5c6b8363a6f073-83474)
# 	+ Description:
#                                 De omgevingsvergunning wordt verleend onder voorwaarden.
#
# 27. 2023_CBS_02615 - Aanvraag omgevingsvergunning Maes LV - nieuwbouw landbouwloods  na afbraak bestaande loods; nieuwbouw carport na sloop garage (2023/237/OMV) - advies college - Goedkeuring (https://data.lommel.be/id/agendapunten/23.1027.8319.3245)
# 	+ Description: ['Het provinciebestuur van Limburg vraagt advies naar aanleiding van een\xa0omgevingsvergunningsaanvraag ingediend door\xa0Maes\xa0LV,\xa0Oude Maai 34\xa0te 3920\xa0Lommel\xa0voor\xa0het\xa0veranderen van het melkveebedrijf (door\xa0de nieuwbouw van een landbouwloods\xa0na afbraak bestaande loods, nieuwbouw carport na sloop garage).\xa0,', 'Het provinciebestuur van Limburg vraagt advies naar aanleiding van een\xa0omgevingsvergunningsaanvraag ingediend door\xa0Maes\xa0LV,\xa0Oude Maai 34\xa0te 3920\xa0Lommel\xa0voor\xa0het\xa0veranderen van het melkveebedrijf (door\xa0de nieuwbouw van een landbouwloods\xa0na afbraak bestaande loods, nieuwbouw carport na sloop garage).\xa0\n']
# 28. 10. DOSS. O/2020/46 TOT HET BOUWEN VAN EEN LANDBOUWLOODS, GELEGEN NIEUWENDAMMEWEG 1, 8620 NIEUWPOORT, KADASTRAAL GEKEND NIEUWPOORT 3° AFD., SECTIE A nr. 174G en 173L. - VRIJGAVE BORGSOM. (https://lblod.nieuwpoort.be/LBLODWeb/id/agendapunt/8bb53d03e5a84886b7b95a23a2e7c24a-55632)
# 	+ Description: ['\n                                DOSS. O/2020/46 TOT HET BOUWEN VAN EEN LANDBOUWLOODS, GELEGEN NIEUWENDAMMEWEG 1, 8620 NIEUWPOORT, KADASTRAAL GEKEND NIEUWPOORT 3° AFD., SECTIE A nr. 174G en 173L. - VRIJGAVE BORGSOM.\n                            ', ',                                DOSS. O/2020/46 TOT HET BOUWEN VAN EEN LANDBOUWLOODS, GELEGEN NIEUWENDAMMEWEG 1, 8620 NIEUWPOORT, KADASTRAAL GEKEND NIEUWPOORT 3° AFD., SECTIE A nr. 174G en 173L. - VRIJGAVE BORGSOM.,                            ']
# 29. 2023_CBS_01459 - Omgevingsvergunning - beroep tegen de omgevingsvergunning voor de functiewijziging van landbouwloods naar opslag - Boezingestraat 150A - Kennisneming (https://data.langemark-poelkapelle.be/id/agendapunten/23.1031.4560.2867)
# 30. 30)  PV op  6 november 2023 van sluiting openbaar onderzoek van aanvraag tot omgevingsvergunning met dossiernummer : OMV/2023/74 over "nieuwbouw landbouwloods, afbraak en nieuwbouw mestsilo, erfverharding, aanleg infiltratiezone, regularisatie sleufsilo's. " op 26 oktober 2023 (https://lblod.kortenaken.be/LBLODWeb/id/agendapunt/0293ae177b094183a285985f56d7648a-19628)
# 	+ Description: [',                                Kennisname PV op  6 november 2023 van sluiting openbaar onderzoek van aanvraag tot omgevingsvergunning met dossiernummer : OMV/2023/74 over "nieuwbouw landbouwloods, afbraak en nieuwbouw mestsilo, erfverharding, aanleg infiltratiezone, regularisatie sleufsilo\'s. " op 26 oktober 2023,                            ', '\n                                Kennisname PV op  6 november 2023 van sluiting openbaar onderzoek van aanvraag tot omgevingsvergunning met dossiernummer : OMV/2023/74 over "nieuwbouw landbouwloods, afbraak en nieuwbouw mestsilo, erfverharding, aanleg infiltratiezone, regularisatie sleufsilo\'s. " op 26 oktober 2023\n                            ']
# 31. 2023_CBS_02399 - ROM2023134- Omgevingsvergunningsaanvraag Vaartdijk 4  - Verzoek tot wijziging  - Goedkeuring (https://data.haacht.be/id/agendapunten/23.1019.2864.7334)
# 	+ Description: Verzoek tot wijziging van de omgevingsvergunningsaanvraag OMV_2023030028 (intern nummer 2023134)  ingediend door de vergunningsaanvrager voor de heropbouw van een landbouwloods, gelegen te Vaartdijk 4, 3150 Haacht, kadastrale omschrijving: afdeling 2 sectie B nr(s). 402C, 405C en 409.Op 17 oktober 2023 werd een nieuwe projectversie overgemaakt met het verzoek de voorgaande te wijzigen. Het college van burgemeester en schepenen is bevoegd om dergelijke wijzigingsverzoek al dan niet te aanvaarden.
# 32. 30)  Goedkeuring advies - OMV/2023/74 -  landbouwloods, de afbraak en nieuwbouw van een mestsilo, erfverharding, de aanleg van een infiltratiezone en de regularisatie van sleufsilo’s - Zandrodestraat 30, 3470 Kortenaken - Raymaekers (https://lblod.kortenaken.be/LBLODWeb/id/agendapunt/01965f3a0cbd4f03a43b26a2873e7eac-19565)
# 	+ Description: ['\n                                Goedkeuring advies - OMV/2023/42 -  landbouwloods, de afbraak en nieuwbouw van een mestsilo, erfverharding, de aanleg van een infiltratiezone en de regularisatie van sleufsilo’s - Zandrodestraat, 3470 Kortenaken\n                            ', ',                                Goedkeuring advies - OMV/2023/42 -  landbouwloods, de afbraak en nieuwbouw van een mestsilo, erfverharding, de aanleg van een infiltratiezone en de regularisatie van sleufsilo’s - Zandrodestraat, 3470 Kortenaken,                            ']
# 33. 16. Aanvraag omgevingsvergunning voor het slopen van bestaande stallen, bouwen van landbouwloods en aanleggen van verharding op de site gelegen Albertstraat 33 te 8980 Zonnebeke  (https://lblod.zonnebeke.be/LBLODWeb/id/agendapunt/4ab59d2ad8a646eab5f66d69c8a3403b-64073)
# 	+ Description: ['\nHet college verleent de omgevingsvergunning.\n', ',Het college verleent de omgevingsvergunning.,']
# 34. 112. BEROEP_LAATSTE_AANLEG - OMV_2022166617 - Omgevingsvergunning verlenen voor het aspect wijzigen van functie woning + landbouwloods naar zonevreemde woning + bijgebouw, gelegen te Reningelst (Poperinge)  (https://lblod.west-vlaanderen.be/LBLODWeb/id/agendapunt/8a219694ed774b1ebb512bf636bcd6ba-152110)
# 	+ Description: [',                                ,                            ', '\n                                \n                            ']
# 35. 2023_CBS_00991 - Omgevingsvergunning 202300071 THOELEN I. - Weigering (https://data.borgloon.be/id/agendapunten/23.1012.5357.3687)
# 	+ Description: De aanvraag omvat de regularisatie van keerwanden, nutsleidingen en verhardingen en de bestemmingswijziging van de bestaande landbouwloods.
# 36. 2023_CBS_02039 - Omgevingsvergunningsaanvraag voor het bouwen van een landbouwloods (=stedenbouwkundige handelingen en de exploitatie van een of meerdere ingedeelde inrichtingen of activiteiten) op perceel afdeling 1 sectie C nrs. 171Y, 171A2, 171B2, 176G en 176F, gelegen St.-Sebastiaanstraat 25 (O2023-00148OP) - Goedkeuring/Weigering (https://data.lummen.be/id/agendapunten/23.1004.0383.2892)
# 	+ Description:  Aanvraag voor het bouwen van een landbouwloods op een perceel, gelegen St.-Sebastiaanstraat 25 kadastraal bekend: afdeling 1 sectie C nrs. 171Y, 171A2, 171B2, 176G en 176F. Uiterste beslissingsdatum: 17/10/2023
# 37. 2023_CBS_01581 - Aanvraag omgevingsvergunning. Het bouwen van een landbouwloods, na het slopen van de bestaande gebouwen, het regulariseren en aanleggen van verhardingen en de aanvraag van een nieuwe ingedeelde klasse 2 te Kloosterstraat 92, ingediend door RV (OMV/2023/0033) - Goedkeuring (https://data.westerlo.be/id/agendapunten/23.1003.7015.6927)
# 38. ['RMT-VGN-2023-0357-BGP-DEP-01', 'RMT-VGN-2023-0357-BGP-DEP-01'] (http://data.lblod.info/id/agendapunten/652679EC5BBE12F8A402A98F)
# 	+ Description: ['Leuven-beroep tegen de weigering van 21 april 2023, voor het bouwen van een landbouwloods met noodwoning en ophoging achterliggend landbouwperceel en exploitatie van een landbouwbedrijf, Sint-Jansbergsesteenweg', 'Leuven-beroep tegen de weigering van 21 april 2023, voor het bouwen van een landbouwloods met noodwoning en ophoging achterliggend landbouwperceel en exploitatie van een landbouwbedrijf, Sint-Jansbergsesteenweg']
# 39. 2. OMV_2023079114 - Aanvraag tot omgevingsvergunning 2023/4922 tot het functiewijziging: landbouwloodsen worden opslagruimtes voor materieel en materiaal (geen landbouw), gelegen in Lendelede, Kortrijksestraat 51, sectie D 345 G, 357 C. (https://lblod.lendelede.be/LBLODWeb/id/agendapunt/58cbd58a3268462bae12317dc9f2cfe7-7280)
# 	+ Description: ['\n                                a) Kennisname dossier.\nb) Openbaar onderzoek van 12.10.2023 tot 10.11.2023\nc) Adviesvraag Dpt Landbouw en Visserij.\n                            ', ',                                a) Kennisname dossier.,b) Openbaar onderzoek van 12.10.2023 tot 10.11.2023,c) Adviesvraag Dpt Landbouw en Visserij.,                            ']
# 40. 2023_CBS_01984 - Omgevingsvergunningsaanvraag voor het bouwen van een landbouwloods (=stedenbouwkundige handelingen en de exploitatie van een of meerdere ingedeelde inrichtingen of activiteiten) op perceel afdeling 1 sectie C nrs. 171Y, 171A2, 171B2, 176G en 176F, gelegen St.-Sebastiaanstraat 25 (O2023-00148OP) - Verdaging (https://data.lummen.be/id/agendapunten/23.0922.5260.2379)
# 	+ Description:  Aanvraag voor het bouwen van een landbouwloods op een perceel, gelegen St.-Sebastiaanstraat 25 kadastraal bekend: afdeling 1 sectie C nrs. 171Y, 171A2, 171B2, 176G en 176F. Uiterste beslissingsdatum: 17/10/2023
#
# ####
# Task: Provide an overview of all the relevant items related to 'landbouwloodsen' mentioned in the context.
# For each item, provide a detailed summary of what the item is about and the link at the end. Group related items by topic and use topic headers. Clarity: Ensure the summaries are clear and straightforward, avoiding unnecessary jargon, verbose descriptions and unnecessary details.
#
#
# Format:
# - **Topic Header**: Start with a topic header to group related items.
#     - **Title**:
#         - **Samenvatting**: A clear and concise summary of the item, including the main points without complex jargon, simple in grammar and structure.
#         - **Link**: Provide the link in brackets at the end.
#
# Example:
# Overzicht van de agendapunten met betrekking tot 'Scaldisstraat':
# - **Verkeersregelment**:
#     - *Wijziging van het aanvullend reglement - Scaldisstraat (inclusief regularisatie en nieuwe parkeerplaats voor autodelen):**
#         - **Samenvatting**: Dit voorstel gaat over het aanpassen van de verkeersregels voor de Scaldisstraat, inclusief het reguleren van bestaande situaties die niet volgens de regels zijn en het creëren van een nieuwe parkeerplaats speciaal voor autodelen.
#         - **Link**: https://data.gent.be/id/agendapunten/22.0111.1538.0398
#     ...
# - **Nuts- en infrastructuurwerken**:
#     - *Toelating voor het uitvoeren van nuts- en infrastructuurwerken - Scaldisstraat 50:**
#         - **Samenvatting**: De aanvraag is om Farys - Klantenwerken - Gent toestemming te geven voor het uitvoeren van nuts- en infrastructuurwerken op Scaldisstraat 50, voornamelijk voor het plaatsen van een drinkwateraftakking.
#         - **Link**: https://data.gent.be/id/agendapunten/23.1017.3020.9047
# ...

# %%
import pandas as pd
import random
from tqdm import tqdm
import numpy as np
import time

def generate_summary_agendapunten(search_term, max_results=40):

    # Sample data based on the search term
    context, results = get_context_for_llm(search_term, None, max_results)
    
    print(f"Found {len(results)} agenda items for '{search_term}'")

    prompt_string, system_message = overview_agendapunten_task(search_term, context, False)
    #print(f"{prompt_string}")

    response = generate_response_openai(system_message, prompt_string)
    response_text = response.choices[0].message.content
    #json_response = extract_json(response)
    if response_text is not None:
        task_info = get_task_info("summary_agendapunten", "summary", "summary_agendapunten", "json", "string", "Dutch")
        save_results_to_file(task_info, search_term, prompt_string, context, system_message, prompt_string, response)

    return response_text

# Sample n random rows from the data
file_path = "data/besluiten_title_description.csv"
print("\n---------------------------------------------------\n")


#search_term = "Raadslid Jurgen Blomme"
#generate_summary_agendapunten(search_term, 5)
# Out:
# ---------------------------------------------------

# %% [markdown]
# # translation tasks

# %%
def generate_translation_task(context, language, format, include_system_message=False):
    task = f"""Task: Translate all fields of the item in the context to {language}, , except for the 'id' field and any field explicitly marked as 'do not translate'. Place names and IDs should remain in their original language. Return the translated text as a JSON object with the following format:


    {format}
    """
    prompt, system = generate_json_prompt(task, json.dumps(context), include_system_message)
    return prompt, system, task, {"context": context, "language": language, "format": format}

def generate_translation_tasks(context, language, format, include_system_message=False):
    task = f"""Task: Translate all fields of each item in the context to {language}, except for the 'id' field and any field explicitly marked as 'do not translate'. Place names and IDs should remain in their original language. Return the translated text as a JSON array, maintaining the original structure and format of each item:
    {{"translations": [{format}, {format}, ...]}}

    """
    prompt, system = generate_json_prompt(task, json.dumps(context), include_system_message)
    return prompt, system, task, {"context": context, "language": language, "format": format}

general_translation_format = """{{"uuid": "Translated title", 
"Text": "Translated description", 
"source": "Source language", 
"target": "Target language"}}"""

agenda_punten_format = """{{
    "Title": "Translated title",
    "Description": "Translated description",
    "source": "Source language",
    "target": "Target language"}}"""


def test_translation_agendapunt(agendapunt):
    print("\n\n---------------------TRANSLATION TASK---------------------\n\n")
    language = "French"
    prompt_string, system_message, task_string, context = generate_translation_task(agendapunt, language, agenda_punten_format)
    print(prompt_string)
    print(system_message)

    print("\n\n---------------------TRANSLATION RESPONSE---------------------\n\n")

    response = generate_response_openai(system_message,prompt_string)
    response_text = response.choices[0].message.content

    json_repsonse = extract_json(response)

    
    if json_repsonse is not None:
        task_info = get_task_info("translate_agendapunt", "translate", "translate_agendapunt", "json", "json", language)
        save_results_to_file(task_info, search_term, task_string, context, system_message, prompt_string, response)

# %%
import os
import time
from tqdm import tqdm
from library.BPMNGraph import BPMNGraph

def get_bpmn_data(graph, with_documentation=True):
    translation_jobs = []
    for id, node in graph.get_nodes():
        node_name = node["name"]
        
        if with_documentation:
            node_documentation = node["documentation"]
            if node_name != '' or node_documentation != '':
                translation_jobs.append({
                    'id': id,
                    'name': node_name,
                    'documentation': node_documentation
                })
        else:
            if node_name != '':
                translation_jobs.append({
                    'id': id,
                    'name': node_name
                })

    return translation_jobs

def translate_bpmn(file_path, languages=["English", "French", "German"]):
    # Create a BPMN graph
    graph = BPMNGraph(file_path)

    translation_jobs = get_bpmn_data(graph, with_documentation=False)
    translation_format = """{'id': 'Do not translate', 'name': 'Translated Name', 'documentation': 'Translated Documentation', 'source': 'Source language', 'target': 'Target language'}"""

    # Initialize progress bar

    for language in languages:
        prompt_string, system_message, task_string, context = generate_translation_tasks(translation_jobs, language, translation_format)
        response = generate_response_openai(system_message,prompt_string, stream=False, json_mode=False, context_length=4096)
        json_response = extract_json(response)  
        if json_response is not None:
            task_info = get_task_info("translate_bpmn", "translate", "translate_bpmn", "bpmn", "json", language)
            save_results_to_file(task_info, file_path, task_string, context, system_message, prompt_string, response)

def translate_bpmn_folder(folder_path, languages=["English", "French", "German"]):
    # Get all .bpmn files in the folder
    bpmn_files = [f for f in os.listdir(folder_path) if f.endswith('.bpmn')]

    # Translate each file, progress bar
    for file in tqdm(bpmn_files, "Translating BPMN files"):
        file_path = os.path.join(folder_path, file)
        translate_bpmn(file_path, languages)

        # Sleep for a while after each call
        time.sleep(1)

#TODO: Rijbewijs, klachtenbehandeling, hoofdprocesProcesMelding (large files) cant fit into the context length

# Translate all BPMN files in the folder
folder_path = "./data/bpmn_to_translate"
translate_bpmn_folder(folder_path, languages=["English", "French", "German"])

# %%
import pandas as pd
import random
from tqdm import tqdm
import numpy as np
import time

def sample_data(file_path, n=10000):
    # Load the data from the file
    data = pd.read_csv(file_path)

    # Replace nan values with an empty string
    data = data.fillna('')

    # Sample n random rows
    sampled_data = data.sample(n)

    # Convert the DataFrame to a list of dictionaries
    sampled_data_dicts = sampled_data.to_dict('records')

    # Replace non-breaking spaces with regular spaces
    sampled_data_dicts = [{k: str(v).replace('\xa0', ' ') for k, v in d.items()} for d in sampled_data_dicts]

    return sampled_data_dicts

def generate_translation_training_agendapunten(file_path, num_samples=50000):

    sampled_agendapunten = sample_data(file_path, n=num_samples)

    languages = ["English", "French", "German"]

    # Create an index for slicing
    index = 0

    for _ in tqdm(range(len(sampled_agendapunten) // 10 + 1)):  # +1 to ensure we cover all items
        # Choose a random batch size between 1 and 10
        batch_size = np.random.choice(range(2, 11))

        # Get the batch from the list
        batch = sampled_agendapunten[index:index + batch_size]

        random_language = random.choice(languages)

        agenda_punten_format = """{{
            "uri": "Do not translate",
            "title": "Translated title",
            "description": "Translated description",
            "source": "Source language",
            "target": "Target language"}}"""

        prompt_string, system_message, task_string, context = generate_translation_tasks(batch, random_language, agenda_punten_format)

        response = generate_response_openai(system_message,prompt_string)
        response_text = response.choices[0].message.content
        json_response = extract_json(response)
        if json_response is not None:
            task_info = get_task_info("translate_agendapunten", "translate", "translate_agendapunten", "json", "json", random_language)
            save_results_to_file(task_info, random_language, task_string, context, system_message, prompt_string, response)

        # Sleep for a while after each call
        time.sleep(1)

        # Update the index for the next batch
        index += batch_size

# Sample n random rows from the data
file_path = "data/besluiten_title_description.csv"
#generate_translation_training_agendapunten(file_path, 10000)

# %% [markdown]
# # Classification methods

# %%
import os
import time
from tqdm import tqdm
from library.BPMNGraph import BPMNGraph

def generate_classification_task(context, taxonomy, include_system_message=True):

    task_string = """

    You are an expert in classifying text data based on a provided context and a predefined hierarchy. The hierarchy is provided in JSON format. Your task is to classify the given text according to this hierarchy and the context provided. If none of the existing classes or subclasses apply, you may generate new ones.

    Here is the classification hierarchy:

    {taxonomy}

    Classify the document provided in context according to the hierarchy. If no suitable class exists within the provided hierarchy, suggest a new one. A document can belong to multiple classes or subclasses. Ensure that the classification is accurate and specific to the context provided.

    Desired Output:
    Output the classification path or the new class suggestion in a JSON format, like this:
    {{
        "classification": {{
            "Category1": ["Subcategory1", "Subcategory2"],
            "Category2": ["Subcategory3"]
        }}
    }}
    or
    {{
        "classification": {{
            "name_new_category_1": ["name_new_subcategory_1"],
            "name_new_category_2": ["name_new_subcategory_2", "name_new_subcategory_3"]
        }}
    }}

    """

    task = task_string.format(taxonomy=json.dumps(taxonomy, indent=4))
    prompt, system = generate_json_prompt(task, context, include_system_message)

    return prompt, system, task, {"context": context, "taxonomy": taxonomy}

def get_classification_data(graph, with_documentation=True):
    translation_jobs = []
    for id, node in graph.get_nodes():
        node_name = node["name"]
        
        if with_documentation:
            node_documentation = node["documentation"]
            if node_name != '' or node_documentation != '':
                translation_jobs.append({
                    'id': id,
                    'name': node_name,
                    'documentation': node_documentation
                })
        else:
            if node_name != '':
                translation_jobs.append({
                    'id': id,
                    'name': node_name
                })

    return translation_jobs

import json

def classify_text(text, taxonomy):
    # Generate the classification task
    prompt_string, system_message, _, _ = generate_classification_task(text, taxonomy)

    # Generate the response using OpenAI (or any other method)
    response = generate_response_openai(system_message, prompt_string, stream=False, json_mode=False)

    return response.choices[0].message.content

def classify_json(json_object, taxonomy):
    # Convert the JSON object to a string
    text = json.dumps(json_object)

    # Classify the text
    response_text = classify_text(text, taxonomy, context=json_object)
    response_json = extract_json(response_text)
    return response_json

def classify_agendapunt(agendapunt, taxonomy):
    # Convert the JSON object to a string
    text = json.dumps(agendapunt)

    # Generate the classification task
    prompt_string, system_message, task_string, context = generate_classification_task(text, taxonomy)

    # Generate the response using OpenAI (or any other method)
    response = generate_response_openai(system_message, prompt_string, stream=False, json_mode=False)
    response_json = extract_json(response)

    if response_json is not None:
        task_info = get_task_info("classification_agendapunt", "classification", "classification_agendapunt", "json", "json") 
        save_results_to_file(task_info, text, task_string, context, system_message, prompt_string, response)

def classify_bpmn(file_path, taxonomy):
    # Create a BPMN graph
    graph = BPMNGraph(file_path)

    classification_data = get_classification_data(graph)

    prompt_string, system_message, task_string, context = generate_classification_task(classification_data, taxonomy)
    response = generate_response_openai(system_message,prompt_string, stream=False, json_mode=False)
    response_json = extract_json(response)
    if response_json is not None:
        task_info = get_task_info("classification_bpmn", "classification", "classification_bpmn", "bpmn", "json")
        save_results_to_file("classification_bpmn", file_path, task_string, context, system_message, prompt_string, response)

def classify_bpmn_folder(folder_path, taxonomy):
    # Get all .bpmn files in the folder
    bpmn_files = [f for f in os.listdir(folder_path) if f.endswith('.bpmn')]

    # Translate each file, progress bar
    for file in tqdm(bpmn_files, "Classify BPMN files"):
        file_path = os.path.join(folder_path, file)
        classify_bpmn(file_path, taxonomy)

        # Sleep for a while after each call
        time.sleep(1)

# %%
import pandas as pd
import random
from tqdm import tqdm
import numpy as np
import time

def sample_data(file_path, n=10000):
    # Load the data from the file
    data = pd.read_csv(file_path)

    # Replace nan values with an empty string
    data = data.fillna('')

    # Sample n random rows
    sampled_data = data.sample(n)

    # Convert the DataFrame to a list of dictionaries
    sampled_data_dicts = sampled_data.to_dict('records')

    # Replace non-breaking spaces with regular spaces
    sampled_data_dicts = [{k: str(v).replace('\xa0', ' ') for k, v in d.items()} for d in sampled_data_dicts]

    return sampled_data_dicts

def generate_classification_training_agendapunten(file_path,taxonomy, num_samples=10000):
    sampled_agendapunten = sample_data(file_path, n=num_samples)

    for sample in tqdm(sampled_agendapunten):  # +1 to ensure we cover all items
        classify_agendapunt(sample, taxonomy)

        
taxonomy_agendapunten = json.load(open("agendapunten_categories.json"))

# Sample n random rows from the data
file_path = "data/besluiten_title_description.csv"
generate_classification_training_agendapunten(file_path, taxonomy_agendapunten, 10000)
# Out:
#  25%|██▌       | 2527/10000 [18:38:58<55:09:05, 26.57s/it]
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpx\_transports\default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpcore\_sync\connection.py:99, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
# ---> 99     raise exc
#     101 return self._connection.handle_request(request)
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpcore\_sync\connection.py:76, in HTTPConnection.handle_request(self, request)
#      75 if self._connection is None:
# ---> 76     stream = self._connect(request)
#      78     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpcore\_sync\connection.py:122, in HTTPConnection._connect(self, request)
#     121 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 122     stream = self._network_backend.connect_tcp(**kwargs)
#     123     trace.return_value = stream
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpcore\_backends\sync.py:205, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     200 exc_map: ExceptionMapping = {
#     201     socket.timeout: ConnectTimeout,
#     202     OSError: ConnectError,
#     203 }
# --> 205 with map_exceptions(exc_map):
#     206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\openai\_base_client.py:950, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     949 try:
# --> 950     response = self._client.send(
#     951         request,
#     952         stream=stream or self._should_stream_response_body(request=request),
#     953         **kwargs,
#     954     )
#     955 except httpx.TimeoutException as err:
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpx\_client.py:1015, in Client._send_single_request(self, request)
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpx\_transports\default.py:232, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
# --> 232 with map_httpcore_exceptions():
#     233     resp = self._pool.handle_request(req)
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\httpx\_transports\default.py:86, in map_httpcore_exceptions()
#      85 message = str(exc)
# ---> 86 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[98], line 38
#      36 # Sample n random rows from the data
#      37 file_path = "data/besluiten_title_description.csv"
# ---> 38 generate_classification_training_agendapunten(file_path, taxonomy_agendapunten, 10000)
#
# Cell In[98], line 29, in generate_classification_training_agendapunten(file_path, taxonomy, num_samples)
#      26 sampled_agendapunten = sample_data(file_path, n=num_samples)
#      28 for sample in tqdm(sampled_agendapunten):  # +1 to ensure we cover all items
# ---> 29     classify_agendapunt(sample, taxonomy)
#
# Cell In[94], line 91, in classify_agendapunt(agendapunt, taxonomy)
#      88 prompt_string, system_message, task_string, context = generate_classification_task(text, taxonomy)
#      90 # Generate the response using OpenAI (or any other method)
# ---> 91 response = generate_response_openai(system_message, prompt_string, stream=False, json_mode=False)
#      93 # Save the results to a file (or any other desired output)
#      94 save_results_to_file("classification_agendapunt", text, task_string, context, system_message, prompt_string, response)
#
# Cell In[92], line 35, in generate_response_openai(system_message, prompt_string, stream, json_mode, context_length)
#      30 def generate_response_openai(system_message,prompt_string, stream=False, json_mode=False, context_length=4096):
#      31
#      32     # Set the response_format based on the json_mode parameter
#      33     response_format = {"type": "json_object"} if json_mode else None
# ---> 35     response = client.chat.completions.create(
#      36         model= OPENAI_DEPLOYMENT_NAME,
#      37         response_format=response_format,
#      38         messages=[
#      39             {"role": "system", "content": system_message},
#      40             {"role": "user", "content": prompt_string},
#      41         ],
#      42         temperature=0.0,
#      43         max_tokens=context_length,
#      44         stream=stream,
#      45         )
#      47     return response
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\openai\_utils\_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\openai\resources\chat\completions.py:581, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     550 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     551 def create(
#     552     self,
#    (...)
#     579     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     580 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 581     return self._post(
#     582         "/chat/completions",
#     583         body=maybe_transform(
#     584             {
#     585                 "messages": messages,
#     586                 "model": model,
#     587                 "frequency_penalty": frequency_penalty,
#     588                 "function_call": function_call,
#     589                 "functions": functions,
#     590                 "logit_bias": logit_bias,
#     591                 "logprobs": logprobs,
#     592                 "max_tokens": max_tokens,
#     593                 "n": n,
#     594                 "presence_penalty": presence_penalty,
#     595                 "response_format": response_format,
#     596                 "seed": seed,
#     597                 "stop": stop,
#     598                 "stream": stream,
#     599                 "temperature": temperature,
#     600                 "tool_choice": tool_choice,
#     601                 "tools": tools,
#     602                 "top_logprobs": top_logprobs,
#     603                 "top_p": top_p,
#     604                 "user": user,
#     605             },
#     606             completion_create_params.CompletionCreateParams,
#     607         ),
#     608         options=make_request_options(
#     609             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     610         ),
#     611         cast_to=ChatCompletion,
#     612         stream=stream or False,
#     613         stream_cls=Stream[ChatCompletionChunk],
#     614     )
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\openai\_base_client.py:1232, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1218 def post(
#    1219     self,
#    1220     path: str,
#    (...)
#    1227     stream_cls: type[_StreamT] | None = None,
#    1228 ) -> ResponseT | _StreamT:
#    1229     opts = FinalRequestOptions.construct(
#    1230         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1231     )
# -> 1232     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\openai\_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\openai\_base_client.py:974, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     971 log.debug("Encountered Exception", exc_info=True)
#     973 if retries > 0:
# --> 974     return self._retry_request(
#     975         options,
#     976         cast_to,
#     977         retries,
#     978         stream=stream,
#     979         stream_cls=stream_cls,
#     980         response_headers=None,
#     981     )
#     983 log.debug("Raising connection error")
#     984 raise APIConnectionError(request=request) from err
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\openai\_base_client.py:1045, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1041 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1042 # different thread if necessary.
#    1043 time.sleep(timeout)
# -> 1045 return self._request(
#    1046     options=options,
#    1047     cast_to=cast_to,
#    1048     remaining_retries=remaining,
#    1049     stream=stream,
#    1050     stream_cls=stream_cls,
#    1051 )
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\openai\_base_client.py:974, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     971 log.debug("Encountered Exception", exc_info=True)
#     973 if retries > 0:
# --> 974     return self._retry_request(
#     975         options,
#     976         cast_to,
#     977         retries,
#     978         stream=stream,
#     979         stream_cls=stream_cls,
#     980         response_headers=None,
#     981     )
#     983 log.debug("Raising connection error")
#     984 raise APIConnectionError(request=request) from err
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\openai\_base_client.py:1045, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1041 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1042 # different thread if necessary.
#    1043 time.sleep(timeout)
# -> 1045 return self._request(
#    1046     options=options,
#    1047     cast_to=cast_to,
#    1048     remaining_retries=remaining,
#    1049     stream=stream,
#    1050     stream_cls=stream_cls,
#    1051 )
#
# File c:\Users\StefaanVercoutere\OneDrive - Sirus NV\OPH\gnn-citations\.conda\Lib\site-packages\openai\_base_client.py:984, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     974         return self._retry_request(
#     975             options,
#     976             cast_to,
#    (...)
#     980             response_headers=None,
#     981         )
#     983     log.debug("Raising connection error")
# --> 984     raise APIConnectionError(request=request) from err
#     986 log.debug(
#     987     'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     988 )
#     990 try:
#
# APIConnectionError: Connection error.
